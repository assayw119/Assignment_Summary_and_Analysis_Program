# %% [markdown]
# ## 파일 불러오기 및 형태소

# %%
import olefile
import zlib
import struct

# %%
# file_name = input('파일명: ')
file_name = '2020113128_권수아.hwp'

if file_name.split('.')[-1] == 'hwp':
    f = olefile.OleFileIO(file_name)
    encoded_text = f.openstream('\005HwpSummaryInformation').read()
    decoded_text = encoded_text.decode('utf-16', errors='ignore')
    print(decoded_text)
# Out:
# ؂Ȁ悶ꊟ愐퐑듆`韀鶌Ā悶ꊟ愐퐑듆`韀鶌　꤁฀Ȁ砀̀萀Ѐ退᐀ꀀԀ؀ࠀऀЁఀ栁ഀ琁଀老฀谁ᔀ鐁鰁ἀĀἀĀἀЀ峍㇁ἀ᠀㈀　㈀　䒱 㐀퓆 ㄀糇 Ⓠӈ ㄀　㨀㔀㜀㨀㌀　ἀĀἀĀἀ؀㠀㈀㄀　㔀ἀⴀ㠀Ⰰ 㔀Ⰰ 㠀Ⰰ ㄀㘀㜀㜀 圀䤀一㌀㈀䰀䔀圀椀渀搀漀眀猀开唀渀欀渀漀眀渀开嘀攀爀猀椀漀渀䀀灳젇혁䀀탺噢눔혁䀀̀̀ĀĀ

# %%
def get_hwp_text(filename):
    f = olefile.OleFileIO(filename)
    dirs = f.listdir()

    # HWP 파일 검증
    if ["FileHeader"] not in dirs or \
       ["\x05HwpSummaryInformation"] not in dirs:
        raise Exception("Not Valid HWP.")

    # 문서 포맷 압축 여부 확인
    header = f.openstream("FileHeader")
    header_data = header.read()
    is_compressed = (header_data[36] & 1) == 1

    # Body Sections 불러오기
    nums = []
    for d in dirs:
        if d[0] == "BodyText":
            nums.append(int(d[1][len("Section"):]))
    sections = ["BodyText/Section"+str(x) for x in sorted(nums)]

    # 전체 text 추출
    text = ""
    for section in sections:
        bodytext = f.openstream(section)
        data = bodytext.read()
        if is_compressed:
            unpacked_data = zlib.decompress(data, -15)
        else:
            unpacked_data = data
    
        # 각 Section 내 text 추출    
        section_text = ""
        i = 0
        size = len(unpacked_data)
        while i < size:
            header = struct.unpack_from("<I", unpacked_data, i)[0]
            rec_type = header & 0x3ff
            rec_len = (header >> 20) & 0xfff

            if rec_type in [67]:
                rec_data = unpacked_data[i+4:i+4+rec_len]
                section_text += rec_data.decode('utf-16', errors='ignore')
                section_text += "\n"

            i += 4 + rec_len

        text += section_text
        text += "\n"

    return text

# %%
get_hwp_text('2020113128_권수아.hwp')
# Out:
# '\x02捤獥\x00\x00\x00\x00\x02\x02汤捯\x00\x00\x00\x00\x022020년도 1학기 인공지능과 미래사회 개별과제(2차)\r\n2020.4.17\r\n생체 공학의 발전\r\n권수아 (2020113128) \r\n동국대학교 글로벌무역학과\r\nᒦ\x00생체 공학 디자이너인 휴 허 박사는 1982년 산악 등반 사고에서 등산으로 인한 조직 손상으로 두 다리를 절단하는 아픔을 겼었습니다. 휴 허 박사는 본인 몸이 무너졌다고 생각하지 않았으며 사람은 절대 좌절하지 않는다고 외쳤습니다. 하지만 생체 공학적 기술은 항상 부족하다고 느꼈습니다. 휴 허 박사는 다른 사람들의 장애를 제거하는 발전된 기술을 가져야겠다고 결심하여 이러한 기폭제를 통해 바위와 얼음벽을 수직으로 오르는 특화된 수족을 개발하기 시작했습니다. 또한 인공신체가 쉽게 변할 수 있어야 하고 어떤 형태든 잘 수행할 수 있을 정도로 만능이어서 생물학적 능력을 넘어설 수 있는 구조물을 만들어 내야 한다고 생각하여 본인 스스로 높이를 조절하며 키를 크게 할 수 있도록 개발하고 자기 자신이 불쾌하거나 불편하면 스스로 조절할 수 있게 개발하며 본인 몸에 맞춰 발전해나갔습니다. 또한 기술 혁신을 통해 주인공 운동 능력을 더 강하게 하여 장애를 없애주었고 새로운 등산 기술을 배우며 희망을 가져다 줄 수 있었습니다. 주인공은 항상 기술이 엄청나게 발달하여 세상에서 장애를 없앨 수 있고 마비 환자가 외골격 신체를 이용해 걸을 수 있는 세상을 꿈꾸었습니다. 하지만 아직까지 슬프게 세상에는 많은 장애가 만연해 있습니다. 이러한 문제를 해결하기 위해 박사는 MIT 미디어 랩 연구실에 극단적 생체 공학 센터를 설립했습니다. 이 센터의 임무는 기초 과학과 기술적 능력을 증진하여 뇌와 신체의 모든 장애에 대한 생체 메카트로닉스와 인체의 재생성 회복을 가능하도록 하는 곳입니다. 이곳에서는 정상적인 사람들이 서거나 걷고 뛰는지에 대한 연구를 통하여 근육이 하는 일, 척수에 근육이 어떻게 이용되는지 연구하여 무릎, 엉덩이 발목 등 신체 일부분을 만들어 신체 일부분이 되어 주고 있었으며 그 중의 본인이 사용하고 있는 의족 BIOM은 거의 1000명의 환자가 사용하는 등 많은 사람들의 다리가 되어주고 있습니다. 의족의 도움을 받는 많은 사람들 중 발레리나인 아드리안 해스렛 데이비스는 보스턴 테러 사건으로 인해 왼쪽 다리를 잃는 아픔을 겪었습니다. 다리를 잃었지만 그녀는 자연스럽게 다시 춤을 추고 싶어 했습니다. MIT 교수는 그녀를 돕기 위해 의족과 로봇공학, 기계학습, 생체기계학 전문가인 MIT 과학자를 초청하여 200일 이상 연구를 진행하였으며 정상적인 댄서를 초청하여 그들이 어떻게 움직이는지 그리고 무대에서 어떤 힘을 사용하는지 연구하여 그 자료를 통해 춤의 기본 원리와 유연한 춤의 능력에 적용하여 그 지식을 생체 공학적 의족에 내장시켰습니다. 이를 통해 그녀는 다시 춤을 출 수 있는 감동적인 결과를 이루어 낼 수 있었습니다. 우리는 평소에 생체 공학에 대해 크게 관심 두고 있지 않습니다. 하지만 휴 허 박사의 말처럼 우리가 먼저 관심 갖고 기술발전을 통해 앞서 나가야 한다고 생각합니다. 이러한 기술을 통해 여러 사람들의 장애를 없애주는 모습을 보며 몸이 불편하지만 긍정적으로 어려움을 헤쳐나가는 모습에 제 자신을 반성하는 시간을 가질 수 있었습니다. 또한 작지만 자연스럽게 일상생활을 할 수 있는 제 신체에 대해 감사함 또한 느낄 수 있었습니다. 우리 주변에는 많은 사람들이 의족을 필요로 하고 있지만 너무 비싼 가격 때문에 엄두를 내지 못하는 환자들이 많습니다. 하지만 요즘에는 핵심 기술발전과 함께 가격을 낮추어 많은 사람들이 이용할 수 있게 도움을 주는 모습을 볼 수 있었습니다. 최근 우리 주변에서는 절단 장애를 가진 국가유공자를 위해 국가보훈처에서 스마트 의족을 기부하는 사례가 있었습니다. 절단 장애를 가진 국가 유공자를 위해 국가보훈처에서 적극적으로 관심을 가져줘서 감사함과 함께 조금 더 편리한 삶을 누릴 수 있게 되었습니다. 우리는 평소에 관심 두지 않으면 그냥 지나쳤을 일이지만 생체 공학의 발전을 통해 많은 사람들이 관심과 도움을 받는 모습을 보며 저 또한 생체 공학에 대해 찾아보며 많은 사례들을 볼 수 있었습니다. 그리고 조금 더 알아보고 싶어졌습니다. 동영상을 통해 생체 공학의 기술 발전과 함께 장애인과 비장애인을 구분할 수 없는 세상이 되어 몸이 불편하신 분들이 더욱 편하게 운동하고, 사람들의 발과 몸이 되\n\n'

# %% [markdown]
# ## doc file

# %%
# pip install docx2txt
# Out:
# Requirement already satisfied: docx2txt in /Users/parkyoungwoong/opt/anaconda3/lib/python3.9/site-packages (0.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import docx2txt

# %%
text = docx2txt.process('2019113108_김혜영.docx')
print(text)
# Out:
# 우리생활 속의 생체공학
#
#
#
# 김혜영(2019113108)
#
# 동국대학교 글로벌 무역학과
#
#
#
# - (서론1) 동영상의 주요 내용이나 흥미롭거나 관심 있었던 내용 소개
#
# : 이 동영상은 생체공학에 대해 다룬 영상이다. 연설자 휴 허는 산악 등반사고로 동상을 입어 두 다리를 절단한 것을 계기로 사람들의 장애를 제거할 수 있는 기술이 필요하다고 생각하였다. 그는 생체공학이 더 좋아져 언젠가, 미래에는 팔다리 세 군데가 없는 부상도 완전히 회복시킬 수 있어야 한다고 생각하였고 MIT 미디어 랩에 극단적 생체공학 센터를 설립하였다. 그는 여러 연구를 통해 연동이 조직 전체의 변화에 따라 일어나야 하는 최적의 시점을 찾아 생체 공학적 의족을 만들어냈다. 또 그는 미래에는 옷, 신발, 보조기, 인공기관들이 더 이상 디자인되거나 자동화과정으로 생산되는 것이 아닌 자료를 이용한 수치적 체계를 통해 생산될 것이라고 말하였다. 의족 사용하는 두 가지 사례를 더 말한 후 보스톤 테러 사건으로 왼쪽 다리를 잃은 무도회 댄서 아드리안의 이야기를 하였다. 연설자는 그녀에게 의족을 만들어주어 그녀의 삶인 춤으로 되돌아갈 수 있도록 해주자는 생각에 200일 이상 춤에 대해 연구를 하고 아드리안에게 의족을 통해 무대에 설 수 있도록 해주었다. 영상은 아드리안의 춤으로 마무리가 되었다. 생체공학이 미래에 어떤 변화를 불러올지, 그 것이 인간에게 얼마나 도움이 되는지를 설명하는 것이 주요 내용이다.
#
# 나는 그가 두 다리를 절단하였음에도 좌절하지 않고, 오히려 다른 사람의 장애를 제거하는 발전된 기술을 가져야겠다는 미래지향적인 생각을 한 것이정말 대단하다고 생각했다. 만약 나에게 이런 일이 생겼더라면 앞으로 살아갈 미래에 대한 걱정과 좌절이 먼저 앞섰을것 같은데 말이다. 그가 위와 같은 생각을 하였기에 의족을 개발하고 생체공학 센터를 설립하고 연설까지 할 수 있다는 것이라 생각이 되었고 걱정 가득한 부정적인 생각을 먼저 하게 되는 나를 돌아보게 되었던 것 같다. 흥미로웠던 부분은 사례로 나왔던 분들의 영상이었다. 다리와 팔을 잃었지만 의수족을 착용하고 다시 이전과 동일한 삶을 살아간다는 것이 따뜻하면서도 감동받았다.
#
#
#
# - (본론1) 발레리나가 춤출 수 있게 하기 위해 어떤 노력을 해왔나요?
#
# : 의족과 로봇공학, 기계학습, 생체기계학 전문가인 MIT의 과학자를 초청하여 200일 이상의 연구를 거쳐 춤에 대해 연구하였다. 또 정상적인 댄서를 초청하여 그들이 어떻게 움직이는지 그리고 무대에서 어떤 힘을 사용하는지 연구하였고 그 자료를 가져다 춤의 기본 원리와 유연한 춤의 능력에 적용하여 그 지식을 생체 공학적 의족에 내장시켰다.
#
#
#
# - (본론2) 개별질문 소개와 내 생각
#
# : 이 영상을 보고 들었던 질문은 “첫 번째, 과연 연설자 휴 허는 자원이 없었더라도 똑같은 일을 했을까? 그리고 두 번째, 의족을 사용하는 사람 도 많지만 사용하지 않는 분들도 많다. 사용하지 않는 이유는 무엇일까? “ 이다.
#
# 이에 대한 나의 생각은 이와 같다. 첫 번째, 휴 허는 자원이 없었더라도 충분히 똑같은 일을 했을 것이라 생각한다. 그는 수술 받은 지 불과 7주 밖에 되지 않았지만 석고 의족을 낀 상태에서도 절벽을 올랐고, 암벽등반에 최적화된 의족을 만들기 위해 노력을 아끼지 않았다. 이후 마침내 본인에게 최적화된 의족을 만들 수 있었고 아드리안에게도 최고의 선물을 주었다. 이에 나는 휴 허는 자원이 없었더라도 그의 강인한 생각과 열정으로 똑같은 일은 행하였을 거라 생각한다.
#
# 두 번째, 의족을 많이 사용하지 않는 이유는 높은 가격 때문이라고 생각한다. 의족의 가격은 천차만별이지만 가격대가 높게 형성이 되어 있는 반면 지원금을 받는 조건이 있고, 받는다 해도 워낙 높은 가격에 경쟁력이 가장 큰 이유라고 생각된다. 또 지원금은 3년마다 받을 수 있기 때문에 3년이내에 바꾸게 된다면지원금이 지불하게 된다. 이를 생각하면 아찔한 금액이 아닐 수 없을 것이다.
#
#
#
# - (마무리) 기술의 개인의 삶에 대한 영향력을 고려한다면, 기술은 앞으로 어떤 방향으로 발전해가야 할까요?
#
#  : 최근에본 TV 광고가있는데, 선천적 청각장애인 김소희씨에 대한 광고였다. 이 광고 내용은 이와 같다. 선천적으로 귀가 들리지 않아 말을 할 수 없는 김소희씨의 가족들이 한번이라도 이 분의 목소리를 듣고 싶어하고 김소희씨 또한 가족들에게 본인의 목소리를 들려주는 것이 소원이라고 한다. KT에서는 김소희씨의 목소리를 추론하기 위해 가족들의 목소리를 녹음 및 김소희씨의 구강구조를 분석하였다. 이후 기가지니 AI 음성합성 기술을 통해 목소리를 실현시켜 가족들에게 들려주었다. 동영상이 생체공학적으로 의족을 개발한 것이라면, TV 광고는 목소리를 기술을 통해 한정된 것이지만 말을 할 수 있었다. 연설자의 생각처럼 미래에는 장애인들이 장애를 극복할 수 있는 기술이 발전되어야 한다고 생각한다. 비장애인의 편리를 위해 AI가 발달하고 있지만, 비장애인뿐 아니라 장애인도 장애를 극복하고 비장애인과 동일한 삶을 살아갈 수 있도록 발전되어야 한다고 생각한다. 그러나 현재는 기술이 발달했으나 의족 등 가격은 천차만별이고 비싼 가격대에 만만치 않을 것이다. 여러 장애인들이 사용할 수 있도록 앞으로는 금전적인 부분에 대해서도많은 고민과 조정이 필요할 것이다. 또 스마트하게 진화되므로 로봇에 너무 의존해서도 안될 것이다.

# %% [markdown]
# ## 의미망분석

# %%
import pandas as pd
import MeCab

# %%
from eunjeon import Mecab
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_4/z38k78f177v_qkh50ljx5kvw0000gn/T/ipykernel_17934/752616490.py in <module>
# ----> 1 from eunjeon import Mecab
#
# ~/opt/anaconda3/lib/python3.9/site-packages/eunjeon/__init__.py in <module>
#      24 installpath = os.path.dirname(os.path.realpath(__file__))
#      25
# ---> 26 from eunjeon._mecab import Mecab
#
# ~/opt/anaconda3/lib/python3.9/site-packages/eunjeon/_mecab.py in <module>
#      15 from eunjeon import installpath
#      16 from eunjeon.constants import TAGSET
# ---> 17 from eunjeon.mecab import Tagger
#      18
#      19
#
# ~/opt/anaconda3/lib/python3.9/site-packages/eunjeon/mecab.py in <module>
#     133     _newclass = 0
#     134
# --> 135 class DictionaryInfo(_object):
#     136     __swig_setmethods__ = {}
#     137     __setattr__ = lambda self, name, value: _swig_setattr(self, DictionaryInfo, name, value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/eunjeon/mecab.py in DictionaryInfo()
#     139     __getattr__ = lambda self, name: _swig_getattr(self, DictionaryInfo, name)
#     140     __repr__ = _swig_repr
# --> 141     __swig_getmethods__["filename"] = _MeCab.DictionaryInfo_filename_get
#     142     if _newclass:
#     143         filename = _swig_property(_MeCab.DictionaryInfo_filename_get)
#
# AttributeError: 'NoneType' object has no attribute 'DictionaryInfo_filename_get'

# %%
a = MeCab.Tagger('-d /usr/local/lib/mecab/dic/mecab-ko-dic')
ret = a.parse(text)
ret
# Out:
# '우리\tNP,*,F,우리,*,*,*,*\n생활\tNNG,행위,T,생활,*,*,*,*\n속\tNNG,*,T,속,*,*,*,*\n의\tJKG,*,F,의,*,*,*,*\n생체\tNNG,*,F,생체,*,*,*,*\n공학\tNNG,*,T,공학,*,*,*,*\n김혜영\tNNP,인명,T,김혜영,*,*,*,*\n(\tSSO,*,*,*,*,*,*,*\n2019113108\tSN,*,*,*,*,*,*,*\n)\tSSC,*,*,*,*,*,*,*\n동국\tNNG,*,T,동국,*,*,*,*\n대학교\tNNG,*,F,대학교,Compound,*,*,대/NNG/*+학교/NNG/*\n글로벌\tNNG,*,T,글로벌,*,*,*,*\n무역\tNNG,행위,T,무역,*,*,*,*\n학과\tNNG,*,F,학과,*,*,*,*\n-\tSY,*,*,*,*,*,*,*\n(\tSSO,*,*,*,*,*,*,*\n서론\tNNG,*,T,서론,*,*,*,*\n1\tSN,*,*,*,*,*,*,*\n)\tSSC,*,*,*,*,*,*,*\n동영상\tNNG,*,T,동영상,Compound,*,*,동/NNG/*+영상/NNG/*\n의\tJKG,*,F,의,*,*,*,*\n주요\tNNG,*,F,주요,*,*,*,*\n내용\tNNG,*,T,내용,*,*,*,*\n이나\tJC,*,F,이나,*,*,*,*\n흥미\tNNG,정적사태,F,흥미,*,*,*,*\n롭\tXSA,*,T,롭,*,*,*,*\n거나\tEC,*,F,거나,*,*,*,*\n관심\tNNG,행위,T,관심,*,*,*,*\n있\tVA,*,T,있,*,*,*,*\n었\tEP,*,T,었,*,*,*,*\n던\tETM,*,T,던,*,*,*,*\n내용\tNNG,*,T,내용,*,*,*,*\n소개\tNNG,행위,F,소개,*,*,*,*\n:\tSC,*,*,*,*,*,*,*\n이\tMM,~명사,F,이,*,*,*,*\n동영상\tNNG,*,T,동영상,Compound,*,*,동/NNG/*+영상/NNG/*\n은\tJX,*,T,은,*,*,*,*\n생체\tNNG,*,F,생체,*,*,*,*\n공학\tNNG,*,T,공학,*,*,*,*\n에\tJKB,*,F,에,*,*,*,*\n대해\tVV+EC,*,F,대해,Inflect,VV,EC,대하/VV/*+아/EC/*\n다룬\tVV+ETM,*,T,다룬,Inflect,VV,ETM,다루/VV/*+ᆫ/ETM/*\n영상\tNNG,*,T,영상,*,*,*,*\n이\tVCP,*,F,이,*,*,*,*\n다\tEF,*,F,다,*,*,*,*\n.\tSF,*,*,*,*,*,*,*\n연설자\tNNG,*,F,연설자,Compound,*,*,연설/NNG/행위+자/NNG/*\n휴\tIC,*,F,휴,*,*,*,*\n허\tVV,*,F,허,*,*,*,*\n는\tETM,*,T,는,*,*,*,*\n산악\tNNG,장소,T,산악,*,*,*,*\n등\tNNB,*,T,등,*,*,*,*\n반\tXPN,*,T,반,*,*,*,*\n사고\tNNG,*,F,사고,*,*,*,*\n로\tJKB,*,F,로,*,*,*,*\n동상\tNNG,*,T,동상,*,*,*,*\n을\tJKO,*,T,을,*,*,*,*\n입\tVV,*,T,입,*,*,*,*\n어\tEC,*,F,어,*,*,*,*\n두\tMM,~가산명사,F,두,*,*,*,*\n다리\tNNG,*,F,다리,*,*,*,*\n를\tJKO,*,T,를,*,*,*,*\n절단\tNNG,행위,T,절단,*,*,*,*\n한\tXSV+ETM,*,T,한,Inflect,XSV,ETM,하/XSV/*+ᆫ/ETM/*\n것\tNNB,*,T,것,*,*,*,*\n을\tJKO,*,T,을,*,*,*,*\n계기\tNNG,*,F,계기,*,*,*,*\n로\tJKB,*,F,로,*,*,*,*\n사람\tNNG,*,T,사람,*,*,*,*\n들\tXSN,*,T,들,*,*,*,*\n의\tJKG,*,F,의,*,*,*,*\n장애\tNNG,*,F,장애,*,*,*,*\n를\tJKO,*,T,를,*,*,*,*\n제거\tNNG,행위,F,제거,*,*,*,*\n할\tXSV+ETM,*,T,할,Inflect,XSV,ETM,하/XSV/*+ᆯ/ETM/*\n수\tNNB,*,F,수,*,*,*,*\n있\tVV,*,T,있,*,*,*,*\n는\tETM,*,T,는,*,*,*,*\n기술\tNNG,*,T,기술,*,*,*,*\n이\tJKS,*,F,이,*,*,*,*\n필요\tNNG,정적사태,F,필요,*,*,*,*\n하\tXSA,*,F,하,*,*,*,*\n다고\tEC,*,F,다고,*,*,*,*\n생각\tNNG,행위,T,생각,*,*,*,*\n하\tXSV,*,F,하,*,*,*,*\n였\tEP,*,T,였,*,*,*,*\n다\tEF,*,F,다,*,*,*,*\n.\tSF,*,*,*,*,*,*,*\n그\tNP,*,F,그,*,*,*,*\n는\tJX,*,T,는,*,*,*,*\n생체\tNNG,*,F,생체,*,*,*,*\n공학\tNNG,*,T,공학,*,*,*,*\n이\tJKS,*,F,이,*,*,*,*\n더\tMAG,성분부사|정도부사,F,더,*,*,*,*\n좋\tVA,*,T,좋,*,*,*,*\n아\tEC,*,F,아,*,*,*,*\n져\tVX+EC,*,F,져,Inflect,VX,EC,지/VX/*+어/EC/*\n언젠가\tMAG,성분부사|시간부사,F,언젠가,*,*,*,*\n,\tSC,*,*,*,*,*,*,*\n미래\tNNG,*,F,미래,*,*,*,*\n에\tJKB,*,F,에,*,*,*,*\n는\tJX,*,T,는,*,*,*,*\n팔다리\tNNG,*,F,팔다리,Compound,*,*,팔/NNG/*+다리/NNG/*\n세\tMM,~가산명사,F,세,*,*,*,*\n군데\tNNBC,*,F,군데,*,*,*,*\n가\tJKS,*,F,가,*,*,*,*\n없\tVA,*,T,없,*,*,*,*\n는\tETM,*,T,는,*,*,*,*\n부상\tNNG,*,T,부상,*,*,*,*\n도\tJX,*,F,도,*,*,*,*\n완전히\tMAG,성분부사|정도부사,F,완전히,*,*,*,*\n회복\tNNG,상태변화,T,회복,*,*,*,*\n시킬\tXSV+ETM,*,T,시킬,Inflect,XSV,ETM,시키/XSV/*+ᆯ/ETM/*\n수\tNNB,*,F,수,*,*,*,*\n있\tVV,*,T,있,*,*,*,*\n어야\tEC,*,F,어야,*,*,*,*\n한다고\tVX+EC,*,F,한다고,Inflect,VX,EC,하/VX/*+ᆫ다고/EC/*\n생각\tNNG,행위,T,생각,*,*,*,*\n하\tXSV,*,F,하,*,*,*,*\n였\tEP,*,T,였,*,*,*,*\n고\tEC,*,F,고,*,*,*,*\nMIT\tSL,*,*,*,*,*,*,*\n미디어\tNNG,*,F,미디어,*,*,*,*\n랩\tNNG,*,T,랩,*,*,*,*\n에\tJKB,*,F,에,*,*,*,*\n극단\tNNG,*,T,극단,*,*,*,*\n적\tXSN,*,T,적,*,*,*,*\n생체\tNNG,*,F,생체,*,*,*,*\n공학\tNNG,*,T,공학,*,*,*,*\n센터\tNNG,*,F,센터,*,*,*,*\n를\tJKO,*,T,를,*,*,*,*\n설립\tNNG,행위,T,설립,*,*,*,*\n하\tXSV,*,F,하,*,*,*,*\n였\tEP,*,T,였,*,*,*,*\n다\tEF,*,F,다,*,*,*,*\n.\tSF,*,*,*,*,*,*,*\n그\tNP,*,F,그,*,*,*,*\n는\tJX,*,T,는,*,*,*,*\n여러\tMM,~가산명사,F,여러,*,*,*,*\n연구\tNNG,행위,F,연구,*,*,*,*\n를\tJKO,*,T,를,*,*,*,*\n통해\tVV+EC,*,F,통해,Inflect,VV,EC,통하/VV/*+아/EC/*\n연동\tNNG,*,T,연동,*,*,*,*\n이\tJKS,*,F,이,*,*,*,*\n조직\tNNG,*,T,조직,*,*,*,*\n전체\tNNG,*,F,전체,*,*,*,*\n의\tJKG,*,F,의,*,*,*,*\n변화\tNNG,상태변화,F,변화,*,*,*,*\n에\tJKB,*,F,에,*,*,*,*\n따라\tVV+EC,*,F,따라,Inflect,VV,EC,따르/VV/*+아/EC/*\n일어나\tVV,*,F,일어나,*,*,*,*\n야\tEC,*,F,야,*,*,*,*\n하\tVV,*,F,하,*,*,*,*\n는\tETM,*,T,는,*,*,*,*\n최적\tNNG,정적사태,T,최적,*,*,*,*\n의\tJKG,*,F,의,*,*,*,*\n시점\tNNG,*,T,시점, ...

# %%
m = MeCab.Tagger()
te = m.parse(text)
print(te)
# Out:
# 우리	NP,*,F,우리,*,*,*,*
# 생활	NNG,행위,T,생활,*,*,*,*
# 속	NNG,*,T,속,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 김혜영	NNP,인명,T,김혜영,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 2019113108	SN,*,*,*,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 동국	NNG,*,T,동국,*,*,*,*
# 대학교	NNG,*,F,대학교,Compound,*,*,대/NNG/*+학교/NNG/*
# 글로벌	NNG,*,T,글로벌,*,*,*,*
# 무역	NNG,행위,T,무역,*,*,*,*
# 학과	NNG,*,F,학과,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 서론	NNG,*,T,서론,*,*,*,*
# 1	SN,*,*,*,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 동영상	NNG,*,T,동영상,Compound,*,*,동/NNG/*+영상/NNG/*
# 의	JKG,*,F,의,*,*,*,*
# 주요	NNG,*,F,주요,*,*,*,*
# 내용	NNG,*,T,내용,*,*,*,*
# 이나	JC,*,F,이나,*,*,*,*
# 흥미	NNG,정적사태,F,흥미,*,*,*,*
# 롭	XSA,*,T,롭,*,*,*,*
# 거나	EC,*,F,거나,*,*,*,*
# 관심	NNG,행위,T,관심,*,*,*,*
# 있	VA,*,T,있,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 던	ETM,*,T,던,*,*,*,*
# 내용	NNG,*,T,내용,*,*,*,*
# 소개	NNG,행위,F,소개,*,*,*,*
# :	SC,*,*,*,*,*,*,*
# 이	MM,~명사,F,이,*,*,*,*
# 동영상	NNG,*,T,동영상,Compound,*,*,동/NNG/*+영상/NNG/*
# 은	JX,*,T,은,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대해	VV+EC,*,F,대해,Inflect,VV,EC,대하/VV/*+아/EC/*
# 다룬	VV+ETM,*,T,다룬,Inflect,VV,ETM,다루/VV/*+ᆫ/ETM/*
# 영상	NNG,*,T,영상,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 연설자	NNG,*,F,연설자,Compound,*,*,연설/NNG/행위+자/NNG/*
# 휴	IC,*,F,휴,*,*,*,*
# 허	VV,*,F,허,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 산악	NNG,장소,T,산악,*,*,*,*
# 등	NNB,*,T,등,*,*,*,*
# 반	XPN,*,T,반,*,*,*,*
# 사고	NNG,*,F,사고,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 동상	NNG,*,T,동상,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 입	VV,*,T,입,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 두	MM,~가산명사,F,두,*,*,*,*
# 다리	NNG,*,F,다리,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 절단	NNG,행위,T,절단,*,*,*,*
# 한	XSV+ETM,*,T,한,Inflect,XSV,ETM,하/XSV/*+ᆫ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 계기	NNG,*,F,계기,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 사람	NNG,*,T,사람,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 제거	NNG,행위,F,제거,*,*,*,*
# 할	XSV+ETM,*,T,할,Inflect,XSV,ETM,하/XSV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 필요	NNG,정적사태,F,필요,*,*,*,*
# 하	XSA,*,F,하,*,*,*,*
# 다고	EC,*,F,다고,*,*,*,*
# 생각	NNG,행위,T,생각,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 더	MAG,성분부사|정도부사,F,더,*,*,*,*
# 좋	VA,*,T,좋,*,*,*,*
# 아	EC,*,F,아,*,*,*,*
# 져	VX+EC,*,F,져,Inflect,VX,EC,지/VX/*+어/EC/*
# 언젠가	MAG,성분부사|시간부사,F,언젠가,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 미래	NNG,*,F,미래,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 팔다리	NNG,*,F,팔다리,Compound,*,*,팔/NNG/*+다리/NNG/*
# 세	MM,~가산명사,F,세,*,*,*,*
# 군데	NNBC,*,F,군데,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 부상	NNG,*,T,부상,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 완전히	MAG,성분부사|정도부사,F,완전히,*,*,*,*
# 회복	NNG,상태변화,T,회복,*,*,*,*
# 시킬	XSV+ETM,*,T,시킬,Inflect,XSV,ETM,시키/XSV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 어야	EC,*,F,어야,*,*,*,*
# 한다고	VX+EC,*,F,한다고,Inflect,VX,EC,하/VX/*+ᆫ다고/EC/*
# 생각	NNG,행위,T,생각,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# MIT	SL,*,*,*,*,*,*,*
# 미디어	NNG,*,F,미디어,*,*,*,*
# 랩	NNG,*,T,랩,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 극단	NNG,*,T,극단,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 센터	NNG,*,F,센터,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 설립	NNG,행위,T,설립,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 여러	MM,~가산명사,F,여러,*,*,*,*
# 연구	NNG,행위,F,연구,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 통해	VV+EC,*,F,통해,Inflect,VV,EC,통하/VV/*+아/EC/*
# 연동	NNG,*,T,연동,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 조직	NNG,*,T,조직,*,*,*,*
# 전체	NNG,*,F,전체,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 변화	NNG,상태변화,F,변화,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 따라	VV+EC,*,F,따라,Inflect,VV,EC,따르/VV/*+아/EC/*
# 일어나	VV,*,F,일어나,*,*,*,*
# 야	EC,*,F,야,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 최적	NNG,정적사태,T,최적,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 시점	NNG,*,T,시점,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 찾	VV,*,T,찾,*,*,*,*
# 아	EC,*,F,아,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 만들	VV,*,T,만들,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 냈	VX+EP,*,T,냈,Inflect,VX,EP,내/VX/*+었/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 또	MAG,성분부사|시간부사,F,또,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 미래	NNG,*,F,미래,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 옷	NNG,*,T,옷,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 신발	NNG,*,T,신발,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 보조	NNG,*,F,보조,*,*,*,*
# 기	VCP+ETN,*,F,기,Inflect,VCP,ETN,이/VCP/*+기/ETN/*
# ,	SC,*,*,*,*,*,*,*
# 인공	NNG,*,T,인공,*,*,*,*
# 기관	NNG,*,T,기관,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 더	MAG,성분부사|정도부사,F,더,*,*,*,*
# 이상	NNG,*,T,이상,*,*,*,*
# 디자인	NNG,행위,T,디자인,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 거나	EC,*,F,거나,*,*,*,*
# 자동	NNG,정적사태,T,자동,*,*,*,*
# 화	XSN,*,F,화,*,*,*,*
# 과정	NNG,*,T,과정,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 생산	NNG,행위,T,생산,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKC,*,F,이,*,*,*,*
# 아닌	VCN+ETM,*,T,아닌,Inflect,VCN,ETM,아니/VCN/*+ᆫ/ETM/*
# 자료	NNG,*,F,자료,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 이용	NNG,*,T,이용,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 수치	NNG,*,F,수치,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 체계	NNG,*,F,체계,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 통해	VV+EC,*,F,통해,Inflect,VV,EC,통하/VV/*+아/EC/*
# 생산	NNG,행위,T,생산,*,*,*,*
# 될	XSV+ETM,*,T,될,Inflect,XSV,ETM,되/XSV/*+ᆯ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라고	EC,*,F,라고,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 두	MM,~가산명사,F,두,*,*,*,*
# 가지	NNBC,*,F,가지,*,*,*,*
# 사례	NNG,*,F,사례,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 더	MAG,성분부사|정도부사,F,더,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 후	NNG,*,F,후,*,*,*,*
# 보스톤	NNP,인명,T,보스톤,*,*,*,*
# 테러	NNG,*,F,테러,*,*,*,*
# 사건	NNG,*,T,사건,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 왼쪽	NNG,*,T,왼쪽,Compound,*,*,왼/NNG/*+쪽/NNG/*
# 다리	NNG,*,F,다리,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 잃	VV,*,T,잃,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 무도회	NNG,*,F,무도회,Compound,*,*,무도/NNG/*+회/NNG/*
# 댄서	NNG,*,F,댄서,*,*,*,*
# 아드리안	NNP,인명,T,아드리안,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 이야기	NNG,*,F,이야기,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 연설자	NNG,*,F,연설자,Compound,*,*,연설/NNG/행위+자/NNG/*
# 는	JX,*,T,는,*,*,*,*
# 그녀	NP,*,F,그녀,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 만들	VV,*,T,만들,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 주	VX,*,F,주,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 그녀	NP,*,F,그녀,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 삶	NNG,행위,T,삶,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 춤	NNG,행위,T,춤,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 되돌아갈	VV+ETM,*,T,되돌아갈,Inflect,VV,ETM,되돌아가/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 도록	EC,*,T,도록,*,*,*,*
# 해	VV+EC,*,F,해,Inflect,VV,EC,하/VV/*+아/EC/*
# 주	VX,*,F,주,*,*,*,*
# 자는	ETM,*,T,자는,*,*,*,*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 200	SN,*,*,*,*,*,*,*
# 일	NNBC,*,T,일,*,*,*,*
# 이상	NNG,*,T,이상,*,*,*,*
# 춤	NNG,행위,T,춤,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대해	VV+EC,*,F,대해,Inflect,VV,EC,대하/VV/*+아/EC/*
# 연구	NNG,행위,F,연구,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 아드리안	NNP,인명,T,아드리안,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 통해	VV+EC,*,F,통해,Inflect,VV,EC,통하/VV/*+아/EC/*
# 무대	NNG,장소,F,무대,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 설	VV+ETM,*,T,설,Inflect,VV,ETM,서/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 도록	EC,*,T,도록,*,*,*,*
# 해	VV+EC,*,F,해,Inflect,VV,EC,하/VV/*+아/EC/*
# 주	VX,*,F,주,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 영상	NNG,*,T,영상,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 아드리안	NNP,인명,T,아드리안,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 춤	NNG,행위,T,춤,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 마무리	NNG,행위,F,마무리,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 미래	NNG,*,F,미래,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 어떤	MM,~명사,T,어떤,*,*,*,*
# 변화	NNG,상태변화,F,변화,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 불러올지	VV+EC,*,F,불러올지,Inflect,VV,EC,불러오/VV/*+ᆯ지/EC/*
# ,	SC,*,*,*,*,*,*,*
# 그	MM,~명사,F,그,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 인간	NNG,*,T,인간,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 얼마나	MAG,성분부사|정도부사,F,얼마나,*,*,*,*
# 도움	NNG,행위,T,도움,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 는지	EC,*,F,는지,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 설명	NNG,*,T,설명,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 주요	NNG,*,F,주요,*,*,*,*
# 내용	NNG,*,T,내용,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 나	NP,*,F,나,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 두	MM,~가산명사,F,두,*,*,*,*
# 다리	NNG,*,F,다리,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 절단	NNG,행위,T,절단,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였음에도	EP+ETN+JKB+JX,*,F,였음에도,Inflect,EP,JX,았/EP/*+음/ETN/*+에/JKB/*+도/JX/*
# 좌절	NNG,행위,T,좌절,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 오히려	MAJ,*,F,오히려,*,*,*,*
# 다른	MM,~명사,T,다른,*,*,*,*
# 사람	NNG,*,T,사람,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 제거	NNG,행위,F,제거,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 발전	NNG,행위,T,발전,*,*,*,*
# 된	XSV+ETM,*,T,된,Inflect,XSV,ETM,되/XSV/*+ᆫ/ETM/*
# 기술	NNG,*,T,기술,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 가져야	VV+EC+VX,*,F,가져야,Inflect,VV,VX,가지/VV/*+어야/EC/*+하/VX/*
# 겠	EP,*,T,겠,*,*,*,*
# 다는	ETM,*,T,다는,*,*,*,*
# 미래	NNG,*,F,미래,*,*,*,*
# 지향	NNG,행위,T,지향,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 한	VV+ETM,*,T,한,Inflect,VV,ETM,하/VV/*+ᆫ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 정말	MAG,문장부사|양상부사,T,정말,*,*,*,*
# 대단	XR,*,T,대단,*,*,*,*
# 하	XSA,*,F,하,*,*,*,*
# 다고	EC,*,F,다고,*,*,*,*
# 생각	NNG,행위,T,생각,*,*,*,*
# 했	XSV+EP,*,T,했,Inflect,XSV,EP,하/XSV/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 만약	MAG,문장부사|양상부사,T,만약,*,*,*,*
# 나	NP,*,F,나,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 이런	MM,~명사,T,이런,*,*,*,*
# 일	NNG,*,T,일,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 생겼	VV+EP,*,T,생겼,Inflect,VV,EP,생기/VV/*+었/EP/*
# 더라면	EC,*,T,더라면,*,*,*,*
# 앞	NNG,장소,T,앞,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 살아갈	VV+ETM,*,T,살아갈,Inflect,VV,ETM,살아가/VV/*+ᆯ/ETM/*
# 미래	NNG,*,F,미래,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대한	VV+ETM,*,T,대한,Inflect,VV,ETM,대하/VV/*+ᆫ/ETM/*
# 걱정	NNG,정적사태,T,걱정,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 좌절	NNG,행위,T,좌절,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 먼저	MAG,성분부사|시간부사,F,먼저,*,*,*,*
# 앞섰	VV+EP,*,T,앞섰,Inflect,VV,EP,앞서/VV/*+었/EP/*
# 을	ETM,*,T,을,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 은데	EC,*,F,은데,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 위	NNG,*,F,위,*,*,*,*
# 와	JKB,*,F,와,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 개발	NNG,행위,T,개발,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 센터	NNG,*,F,센터,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 설립	NNG,행위,T,설립,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 연설	NNG,행위,T,연설,*,*,*,*
# 까지	JX,*,F,까지,*,*,*,*
# 할	VV+ETM,*,T,할,Inflect,VV,ETM,하/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 다는	ETM,*,T,다는,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라	EC,*,F,라,*,*,*,*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 걱정	NNG,정적사태,T,걱정,*,*,*,*
# 가득	MAG,성분부사|양태부사,T,가득,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 부정	NNG,정적사태,T,부정,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 먼저	MAG,성분부사|시간부사,F,먼저,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 나	NP,*,F,나,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 돌아보	VV,*,F,돌아보,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 던	ETM,*,T,던,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 흥미	NNG,정적사태,F,흥미,*,*,*,*
# 로웠	XSA+EP,*,T,로웠,Inflect,XSA,EP,롭/XSA/*+었/EP/*
# 던	ETM,*,T,던,*,*,*,*
# 부분	NNG,*,T,부분,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 사례	NNG,*,F,사례,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 나왔	VV+EP,*,T,나왔,Inflect,VV,EP,나오/VV/*+았/EP/*
# 던	ETM,*,T,던,*,*,*,*
# 분	NNB,*,T,분,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 영상	NNG,*,T,영상,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 다리	NNG,*,F,다리,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# 팔	NNG,*,T,팔,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 잃	VV,*,T,잃,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 의수족	NNG,*,T,의수족,Compound,*,*,의/NNG/*+수족/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 착용	NNG,행위,T,착용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 다시	MAG,성분부사|시간부사,F,다시,*,*,*,*
# 이전	NNG,*,T,이전,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 동일	NNG,*,T,동일,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 삶	NNG,행위,T,삶,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 살아간다는	VV+ETM,*,T,살아간다는,Inflect,VV,ETM,살아가/VV/*+ᆫ다는/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 따뜻	XR,*,T,따뜻,*,*,*,*
# 하	XSA,*,F,하,*,*,*,*
# 면서	EC,*,F,면서,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 감동	NNG,정적사태,T,감동,*,*,*,*
# 받	VV,*,T,받,*,*,*,*
# 았	EP,*,T,았,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 본론	NNG,*,T,본론,*,*,*,*
# 1	SN,*,*,*,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 발레리나	NNG,*,F,발레리나,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 춤출	VV+ETM,*,T,춤출,Inflect,VV,ETM,춤추/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 위해	VV+EC,*,F,위해,Inflect,VV,EC,위하/VV/*+아/EC/*
# 어떤	MM,~명사,T,어떤,*,*,*,*
# 노력	NNG,*,T,노력,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 해	VV+EC,*,F,해,Inflect,VV,EC,하/VV/*+아/EC/*
# 왔	VX+EP,*,T,왔,Inflect,VX,EP,오/VX/*+았/EP/*
# 나요	EF,*,F,나요,*,*,*,*
# ?	SF,*,*,*,*,*,*,*
# :	SC,*,*,*,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 로봇	NNG,*,T,로봇,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 기계	NNG,*,F,기계,*,*,*,*
# 학습	NNG,행위,T,학습,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 기계학	NNG,*,T,기계학,Compound,*,*,기계/NNG/*+학/NNG/*
# 전문가	NNG,*,F,전문가,Compound,*,*,전문/NNG/*+가/NNG/*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# MIT	SL,*,*,*,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 과학자	NNG,*,F,과학자,Compound,*,*,과학/NNG/*+자/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 초청	NNG,행위,T,초청,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 여	EC,*,F,여,*,*,*,*
# 200	SN,*,*,*,*,*,*,*
# 일	NNBC,*,T,일,*,*,*,*
# 이상	NNG,*,T,이상,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 연구	NNG,행위,F,연구,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 거쳐	VV+EC,*,F,거쳐,Inflect,VV,EC,거치/VV/*+어/EC/*
# 춤	NNG,행위,T,춤,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대해	VV+EC,*,F,대해,Inflect,VV,EC,대하/VV/*+아/EC/*
# 연구	NNG,행위,F,연구,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 또	MAG,성분부사|시간부사,F,또,*,*,*,*
# 정상	NNG,*,T,정상,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 댄서	NNG,*,F,댄서,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 초청	NNG,행위,T,초청,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 여	EC,*,F,여,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 어떻게	MAG,*,F,어떻게,*,*,*,*
# 움직이	VV,*,F,움직이,*,*,*,*
# 는지	EC,*,F,는지,*,*,*,*
# 그리고	MAJ,*,F,그리고,*,*,*,*
# 무대	NNG,장소,F,무대,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 어떤	MM,~명사,T,어떤,*,*,*,*
# 힘	NNG,*,T,힘,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는지	EC,*,F,는지,*,*,*,*
# 연구	NNG,행위,F,연구,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 그	MM,~명사,F,그,*,*,*,*
# 자료	NNG,*,F,자료,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 가져다	VV+EC,*,F,가져다,Inflect,VV,EC,가지/VV/*+어다/EC/*
# 춤	NNG,행위,T,춤,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 기본	NNG,*,T,기본,*,*,*,*
# 원리	NNG,*,F,원리,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# 유연	XR,*,T,유연,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 춤	NNG,행위,T,춤,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 능력	NNG,*,T,능력,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 적용	NNG,행위,T,적용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 여	EC,*,F,여,*,*,*,*
# 그	MM,~명사,F,그,*,*,*,*
# 지식	NNG,*,T,지식,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 내장	NNG,*,T,내장,*,*,*,*
# 시켰	XSV+EP,*,T,시켰,Inflect,XSV,EP,시키/XSV/*+었/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 본론	NNG,*,T,본론,*,*,*,*
# 2	SN,*,*,*,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 개별	NNG,*,T,개별,*,*,*,*
# 질문	NNG,행위,T,질문,*,*,*,*
# 소개	NNG,행위,F,소개,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# 내	NP+JKG,*,F,내,Inflect,NP,JKG,나/NP/*+의/JKG/*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# :	SC,*,*,*,*,*,*,*
# 이	MM,~명사,F,이,*,*,*,*
# 영상	NNG,*,T,영상,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 보	VV,*,F,보,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 들	VX,*,T,들,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 던	ETM,*,T,던,*,*,*,*
# 질문	NNG,행위,T,질문,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# “	SSO,*,*,*,*,*,*,*
# 첫	MM,~명사,T,첫,*,*,*,*
# 번	NNBC,*,T,번,*,*,*,*
# 째	XSN,*,F,째,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 과연	MAG,문장부사|양상부사,T,과연,*,*,*,*
# 연설자	NNG,*,F,연설자,Compound,*,*,연설/NNG/행위+자/NNG/*
# 휴	IC,*,F,휴,*,*,*,*
# 허	VV,*,F,허,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 자원	NNG,*,T,자원,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 더라도	EC,*,F,더라도,*,*,*,*
# 똑같	VA,*,T,똑같,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 일	NNG,*,T,일,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 했	VV+EP,*,T,했,Inflect,VV,EP,하/VV/*+았/EP/*
# 을까	EF,*,F,을까,*,*,*,*
# ?	SF,*,*,*,*,*,*,*
# 그리고	MAJ,*,F,그리고,*,*,*,*
# 두	MM,~가산명사,F,두,*,*,*,*
# 번	NNBC,*,T,번,*,*,*,*
# 째	XSN,*,F,째,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 사람	NNG,*,T,사람,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 많	VA,*,T,많,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 분	NNB,*,T,분,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 많	VA,*,T,많,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 이유	NNG,*,F,이유,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 무엇	NP,*,T,무엇,*,*,*,*
# 일까	VCP+EF,*,F,일까,Inflect,VCP,EF,이/VCP/*+ᆯ까/EF/*
# ?	SF,*,*,*,*,*,*,*
# “	SSO,*,*,*,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대한	VV+ETM,*,T,대한,Inflect,VV,ETM,대하/VV/*+ᆫ/ETM/*
# 나	NP,*,F,나,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 와	JKB,*,F,와,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 첫	MM,~명사,T,첫,*,*,*,*
# 번	NNBC,*,T,번,*,*,*,*
# 째	XSN,*,F,째,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 휴	IC,*,F,휴,*,*,*,*
# 허	VV,*,F,허,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 자원	NNG,*,T,자원,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 더라도	EC,*,F,더라도,*,*,*,*
# 충분히	MAG,성분부사|정도부사,F,충분히,*,*,*,*
# 똑같	VA,*,T,똑같,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 일	NNG,*,T,일,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 했	VV+EP,*,T,했,Inflect,VV,EP,하/VV/*+았/EP/*
# 을	ETM,*,T,을,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라	EC,*,F,라,*,*,*,*
# 생각	NNG,행위,T,생각,*,*,*,*
# 한다	XSV+EF,*,F,한다,Inflect,XSV,EF,하/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 수술	NNG,*,T,수술,*,*,*,*
# 받	VV,*,T,받,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 지	NNB,*,F,지,*,*,*,*
# 불과	MAG,성분부사|정도부사,F,불과,*,*,*,*
# 7	SN,*,*,*,*,*,*,*
# 주	NNBC,*,F,주,*,*,*,*
# 밖에	JX,*,F,밖에,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 았	EP,*,T,았,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 석고	NNG,*,F,석고,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 족	NNG,*,T,족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 낀	VV+ETM,*,T,낀,Inflect,VV,ETM,끼/VV/*+ᆫ/ETM/*
# 상태	NNG,정적사태,F,상태,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 절벽	NNG,*,T,절벽,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 올랐	VV+EP,*,T,올랐,Inflect,VV,EP,오르/VV/*+았/EP/*
# 고	EC,*,F,고,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 암벽등반	NNP,*,T,암벽등반,Compound,*,*,암벽/NNG/장소+등반/NNG/행위
# 에	JKB,*,F,에,*,*,*,*
# 최적	NNG,정적사태,T,최적,*,*,*,*
# 화	XSN,*,F,화,*,*,*,*
# 된	XSV+ETM,*,T,된,Inflect,XSV,ETM,되/XSV/*+ᆫ/ETM/*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 만들	VV,*,T,만들,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 위해	VV+EC,*,F,위해,Inflect,VV,EC,위하/VV/*+아/EC/*
# 노력	NNG,*,T,노력,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 아끼	VV,*,F,아끼,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 았	EP,*,T,았,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 이후	NNG,*,F,이후,*,*,*,*
# 마침내	MAG,문장부사|접속부사,F,마침내,*,*,*,*
# 본인	NNG,*,T,본인,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 최적	NNG,정적사태,T,최적,*,*,*,*
# 화	XSN,*,F,화,*,*,*,*
# 된	XSV+ETM,*,T,된,Inflect,XSV,ETM,되/XSV/*+ᆫ/ETM/*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 만들	VV+ETM,*,T,만들,Inflect,VV,ETM,만들/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 아드리안	NNP,인명,T,아드리안,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 최고	NNG,*,F,최고,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 선물	NNG,*,T,선물,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 주	VV,*,F,주,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 나	NP,*,F,나,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 휴	IC,*,F,휴,*,*,*,*
# 허	VV,*,F,허,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 자원	NNG,*,T,자원,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 더라도	EC,*,F,더라도,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 강인	XR,*,T,강인,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 열정	NNG,정적사태,T,열정,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 똑같	VA,*,T,똑같,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 일	NNG,*,T,일,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 행하	VV,*,F,행하,*,*,*,*
# 였을	EP+ETM,*,T,였을,Inflect,EP,ETM,았/EP/*+을/ETM/*
# 거	NNB,*,F,거,*,*,*,*
# 라	VCP+EC,*,F,라,Inflect,VCP,EC,이/VCP/*+라/EC/*
# 생각	NNG,행위,T,생각,*,*,*,*
# 한다	XSV+EF,*,F,한다,Inflect,XSV,EF,하/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 두	MM,~가산명사,F,두,*,*,*,*
# 번	NNBC,*,T,번,*,*,*,*
# 째	XSN,*,F,째,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 많이	MAG,성분부사|정도부사,F,많이,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 이유	NNG,*,F,이유,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 높	VA,*,T,높,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 가격	NNG,*,T,가격,*,*,*,*
# 때문	NNB,*,T,때문,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라고	EC,*,F,라고,*,*,*,*
# 생각	NNG,행위,T,생각,*,*,*,*
# 한다	XSV+EF,*,F,한다,Inflect,XSV,EF,하/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 가격	NNG,*,T,가격,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 천차만별	NNG,정적사태,T,천차만별,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 가격대	NNG,*,F,가격대,Compound,*,*,가격/NNG/*+대/NNG/*
# 가	JKS,*,F,가,*,*,*,*
# 높	VA,*,T,높,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 형성	NNG,행위,T,형성,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 있	VX,*,T,있,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 반면	NNG,정적사태,T,반면,*,*,*,*
# 지원금	NNG,*,T,지원금,Compound,*,*,지원/NNG/*+금/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 받	VV,*,T,받,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 조건	NNG,*,T,조건,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 받	VV,*,T,받,*,*,*,*
# 는다	EC,*,F,는다,*,*,*,*
# 해도	VV+EC,*,F,해도,Inflect,VV,EC,하/VV/*+아도/EC/*
# 워낙	MAG,*,T,워낙,*,*,*,*
# 높	VA,*,T,높,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 가격	NNG,*,T,가격,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 경쟁력	NNG,정적사태,T,경쟁력,Compound,*,*,경쟁/NNG/행위+력/NNG/*
# 이	JKS,*,F,이,*,*,*,*
# 가장	MAG,성분부사|정도부사,T,가장,*,*,*,*
# 큰	VA+ETM,*,T,큰,Inflect,VA,ETM,크/VA/*+ᆫ/ETM/*
# 이유	NNG,*,F,이유,*,*,*,*
# 라고	VCP+EC,*,F,라고,Inflect,VCP,EC,이/VCP/*+라고/EC/*
# 생각	NNG,행위,T,생각,*,*,*,*
# 된다	XSV+EF,*,F,된다,Inflect,XSV,EF,되/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 또	MAG,성분부사|시간부사,F,또,*,*,*,*
# 지원금	NNG,*,T,지원금,Compound,*,*,지원/NNG/*+금/NNG/*
# 은	JX,*,T,은,*,*,*,*
# 3	SN,*,*,*,*,*,*,*
# 년	NNBC,*,T,년,*,*,*,*
# 마다	JX,*,F,마다,*,*,*,*
# 받	VV,*,T,받,*,*,*,*
# 을	ETM,*,T,을,*,*,*,*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 때문	NNB,*,T,때문,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 3	SN,*,*,*,*,*,*,*
# 년	NNBC,*,T,년,*,*,*,*
# 이내	NNG,*,F,이내,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 바꾸	VV,*,F,바꾸,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 된다면	VV+EC,*,T,된다면,Inflect,VV,EC,되/VV/*+ᆫ다면/EC/*
# 지원금	NNG,*,T,지원금,Compound,*,*,지원/NNG/*+금/NNG/*
# 이	JKS,*,F,이,*,*,*,*
# 지불	NNG,행위,T,지불,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 된다	VV+EF,*,F,된다,Inflect,VV,EF,되/VV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 생각	NNG,행위,T,생각,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 면	EC,*,T,면,*,*,*,*
# 아찔	XR,*,T,아찔,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 금액	NNG,*,T,금액,*,*,*,*
# 이	JKC,*,F,이,*,*,*,*
# 아닐	VCN+ETM,*,T,아닐,Inflect,VCN,ETM,아니/VCN/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 을	ETM,*,T,을,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 마무리	NNG,행위,F,마무리,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 개인	NNG,*,T,개인,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 삶	NNG,행위,T,삶,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대한	VV+ETM,*,T,대한,Inflect,VV,ETM,대하/VV/*+ᆫ/ETM/*
# 영향력	NNG,*,T,영향력,Compound,*,*,영향/NNG/*+력/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 고려	NNG,행위,F,고려,*,*,*,*
# 한다면	XSV+EC,*,T,한다면,Inflect,XSV,EC,하/XSV/*+ᆫ다면/EC/*
# ,	SC,*,*,*,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 앞	NNG,장소,T,앞,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 어떤	MM,~명사,T,어떤,*,*,*,*
# 방향	NNG,*,T,방향,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 발전	NNG,행위,T,발전,*,*,*,*
# 해	XSV+EC,*,F,해,Inflect,XSV,EC,하/XSV/*+아/EC/*
# 가	VX,*,F,가,*,*,*,*
# 야	EC,*,F,야,*,*,*,*
# 할까요	VX+EC,*,F,할까요,Inflect,VX,EC,하/VX/*+ᆯ까요/EC/*
# ?	SY,*,*,*,*,*,*,*
# :	SC,*,*,*,*,*,*,*
# 최근	NNG,*,T,최근,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 본	VV+ETM,*,T,본,Inflect,VV,ETM,보/VV/*+ᆫ/ETM/*
# TV	SL,*,*,*,*,*,*,*
# 광고	NNG,*,F,광고,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 있	VA,*,T,있,*,*,*,*
# 는데	EC,*,F,는데,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 선천	NNG,*,T,선천,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 청각	NNG,*,T,청각,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 김소희	NNP,인명,F,김소희,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대한	VV+ETM,*,T,대한,Inflect,VV,ETM,대하/VV/*+ᆫ/ETM/*
# 광고	NNG,*,F,광고,*,*,*,*
# 였	VCP+EP,*,T,였,Inflect,VCP,EP,이/VCP/*+었/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 이	MM,~명사,F,이,*,*,*,*
# 광고	NNG,*,F,광고,*,*,*,*
# 내용	NNG,*,T,내용,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 와	JKB,*,F,와,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 선천	NNG,*,T,선천,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 귀	NNG,*,F,귀,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 들리	VV,*,F,들리,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 아	EC,*,F,아,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 할	VV+ETM,*,T,할,Inflect,VV,ETM,하/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 김소희	NNP,인명,F,김소희,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 가족	NNG,*,T,가족,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 한	MM,~가산명사,T,한,*,*,*,*
# 번	NNBC,*,T,번,*,*,*,*
# 이라도	JX,*,F,이라도,*,*,*,*
# 이	NR,*,F,이,*,*,*,*
# 분	NNBC,*,T,분,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 듣	VV,*,T,듣,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 싶	VX,*,T,싶,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 김소희	NNP,인명,F,김소희,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 또한	MAJ,*,T,또한,*,*,*,*
# 가족	NNG,*,T,가족,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 본인	NNG,*,T,본인,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 들려주	VV,*,F,들려주,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 소원	NNG,정적사태,T,소원,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라고	EC,*,F,라고,*,*,*,*
# 한다	VX+EF,*,F,한다,Inflect,VX,EF,하/VX/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# KT	SL,*,*,*,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 김소희	NNP,인명,F,김소희,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 추론	NNG,*,T,추론,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 위해	VV+EC,*,F,위해,Inflect,VV,EC,위하/VV/*+아/EC/*
# 가족	NNG,*,T,가족,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 녹	VV,*,T,녹,*,*,*,*
# 음	ETN,*,T,음,*,*,*,*
# 및	MAJ,*,T,및,*,*,*,*
# 김소희	NNP,인명,F,김소희,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 구강	NNG,*,T,구강,*,*,*,*
# 구조	NNG,*,F,구조,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 분석	NNG,행위,T,분석,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 이후	NNG,*,F,이후,*,*,*,*
# 기	VCP+EC,*,F,기,Inflect,VCP,EC,이/VCP/*+기/EC/*
# 가지	VX,*,F,가지,*,*,*,*
# 니	EC,*,F,니,*,*,*,*
# AI	SL,*,*,*,*,*,*,*
# 음성	NNG,*,T,음성,*,*,*,*
# 합성	NNG,*,T,합성,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 통해	VV+EC,*,F,통해,Inflect,VV,EC,통하/VV/*+아/EC/*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 실현	NNG,행위,T,실현,*,*,*,*
# 시켜	XSV+EC,*,F,시켜,Inflect,XSV,EC,시키/XSV/*+어/EC/*
# 가족	NNG,*,T,가족,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 들려	VV+EC,*,F,들려,Inflect,VV,EC,들리/VV/*+어/EC/*
# 주	VX,*,F,주,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 동영상	NNG,*,T,동영상,Compound,*,*,동/NNG/*+영상/NNG/*
# 이	JKS,*,F,이,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 개발	NNG,행위,T,개발,*,*,*,*
# 한	XSV+ETM,*,T,한,Inflect,XSV,ETM,하/XSV/*+ᆫ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라면	EC,*,T,라면,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# TV	SL,*,*,*,*,*,*,*
# 광고	NNG,*,F,광고,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 통해	VV+EC,*,F,통해,Inflect,VV,EC,통하/VV/*+아/EC/*
# 한정	NNG,*,T,한정,*,*,*,*
# 된	XSV+ETM,*,T,된,Inflect,XSV,ETM,되/XSV/*+ᆫ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 할	VV+ETM,*,T,할,Inflect,VV,ETM,하/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 연설자	NNG,*,F,연설자,Compound,*,*,연설/NNG/행위+자/NNG/*
# 의	JKG,*,F,의,*,*,*,*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 처럼	JKB,*,T,처럼,*,*,*,*
# 미래	NNG,*,F,미래,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 인	XSN,*,T,인,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 극복	NNG,행위,T,극복,*,*,*,*
# 할	XSV+ETM,*,T,할,Inflect,XSV,ETM,하/XSV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 발전	NNG,행위,T,발전,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 어야	EC,*,F,어야,*,*,*,*
# 한다고	VX+EC,*,F,한다고,Inflect,VX,EC,하/VX/*+ᆫ다고/EC/*
# 생각	NNG,행위,T,생각,*,*,*,*
# 한다	XSV+EF,*,F,한다,Inflect,XSV,EF,하/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 비장	NNG,*,T,비장,*,*,*,*
# 애인	NNG,*,T,애인,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 편리	NNG,*,F,편리,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 위해	VV+EC,*,F,위해,Inflect,VV,EC,위하/VV/*+아/EC/*
# AI	SL,*,*,*,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 발달	NNG,행위,T,발달,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 있	VX,*,T,있,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 비	XPN,*,F,비,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 뿐	NNB,*,T,뿐,*,*,*,*
# 아니	VCN,*,F,아니,*,*,*,*
# 라	EC,*,F,라,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 인도	NNP,지명,F,인도,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 극복	NNG,행위,T,극복,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 비장	NNG,*,T,비장,*,*,*,*
# 애인	NNG,*,T,애인,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 동일	NNG,*,T,동일,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 삶	NNG,행위,T,삶,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 살아갈	VV+ETM,*,T,살아갈,Inflect,VV,ETM,살아가/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 도록	EC,*,T,도록,*,*,*,*
# 발전	NNG,상태변화,T,발전,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 어야	EC,*,F,어야,*,*,*,*
# 한다고	VX+EC,*,F,한다고,Inflect,VX,EC,하/VX/*+ᆫ다고/EC/*
# 생각	NNG,행위,T,생각,*,*,*,*
# 한다	XSV+EF,*,F,한다,Inflect,XSV,EF,하/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 그러나	MAJ,*,F,그러나,*,*,*,*
# 현재	NNG,*,F,현재,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 발달	NNG,행위,T,발달,*,*,*,*
# 했으나	XSV+EP+EC,*,F,했으나,Inflect,XSV,EC,하/XSV/*+았/EP/*+으나/EC/*
# 의족	NNG,*,T,의족,*,*,*,*
# 등	NNB,*,T,등,*,*,*,*
# 가격	NNG,*,T,가격,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 천차만별	NNG,정적사태,T,천차만별,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 비싼	VA+ETM,*,T,비싼,Inflect,VA,ETM,비싸/VA/*+ᆫ/ETM/*
# 가격대	NNG,*,F,가격대,Compound,*,*,가격/NNG/*+대/NNG/*
# 에	JKB,*,F,에,*,*,*,*
# 만만	XR,*,T,만만,*,*,*,*
# 치	XSA+EC,*,F,치,Inflect,XSA,EC,하/XSA/*+지/EC/*
# 않	VX,*,T,않,*,*,*,*
# 을	ETM,*,T,을,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 여러	MM,~가산명사,F,여러,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 인	XSN,*,T,인,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 할	XSV+ETM,*,T,할,Inflect,XSV,ETM,하/XSV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 도록	EC,*,T,도록,*,*,*,*
# 앞	NNG,장소,T,앞,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 금전	NNG,*,T,금전,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 부분	NNG,*,T,부분,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대해서	VV+EC,*,F,대해서,Inflect,VV,EC,대하/VV/*+아서/EC/*
# 도	JX,*,F,도,*,*,*,*
# 많	VA,*,T,많,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 고민	NNG,*,T,고민,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 조정	NNG,*,T,조정,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 필요	NNG,정적사태,F,필요,*,*,*,*
# 할	XSV+ETM,*,T,할,Inflect,XSV,ETM,하/XSV/*+ᆯ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 또	MAG,성분부사|시간부사,F,또,*,*,*,*
# 스마트	NNG,*,F,스마트,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 진화	NNG,*,F,진화,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 므로	EC,*,F,므로,*,*,*,*
# 로봇	NNG,*,T,로봇,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 너무	MAG,성분부사|정도부사,F,너무,*,*,*,*
# 의존	NNG,행위,T,의존,*,*,*,*
# 해서	XSV+EC,*,F,해서,Inflect,XSV,EC,하/XSV/*+아서/EC/*
# 도	JX,*,F,도,*,*,*,*
# 안	MAG,성분부사|부정부사,T,안,*,*,*,*
# 될	VV+ETM,*,T,될,Inflect,VV,ETM,되/VV/*+ᆯ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# EOS

# %%
df = pd.read_excel('stopwords.xlsx')
stopwords = list(df['불용어'])
stopwords
# Out:
# ['아',
#  '휴',
#  '아이구',
#  '아이쿠',
#  '아이고',
#  '어',
#  '나',
#  '우리',
#  '저희',
#  '따라',
#  '의해',
#  '을',
#  '를',
#  '에',
#  '의',
#  '가',
#  '으로',
#  '로',
#  '에게',
#  '뿐이다',
#  '의거하여',
#  '근거하여',
#  '입각하여',
#  '기준으로',
#  '예하면',
#  '예를 들면',
#  '예를 들자면',
#  '저',
#  '소인',
#  '소생',
#  '저희',
#  '지말고',
#  '하지마',
#  '하지마라',
#  '다른',
#  '물론',
#  '또한',
#  '그리고',
#  '비길수 없다',
#  '해서는 안된다',
#  '뿐만 아니라',
#  '만이 아니다',
#  '만은 아니다',
#  '막론하고',
#  '관계없이',
#  '그치지 않다',
#  '그러나',
#  '그런데',
#  '하지만',
#  '든간에',
#  '논하지 않다',
#  '따지지 않다',
#  '설사',
#  '비록',
#  '더라도',
#  '아니면',
#  '만 못하다',
#  '하는 편이 낫다',
#  '불문하고',
#  '향하여',
#  '향해서',
#  '향하다',
#  '쪽으로',
#  '틈타',
#  '이용하여',
#  '타다',
#  '오르다',
#  '제외하고',
#  '이 외에',
#  '이 밖에',
#  '하여야',
#  '비로소',
#  '한다면 몰라도',
#  '외에도',
#  '이곳',
#  '여기',
#  '부터',
#  '기점으로',
#  '따라서',
#  '할 생각이다',
#  '하려고하다',
#  '이리하여',
#  '그리하여',
#  '그렇게 함으로써',
#  '하지만',
#  '일때',
#  '할때',
#  '앞에서',
#  '중에서',
#  '보는데서',
#  '으로써',
#  '로써',
#  '까지',
#  '해야한다',
#  '일것이다',
#  '반드시',
#  '할줄알다',
#  '할수있다',
#  '할수있어',
#  '임에 틀림없다',
#  '한다면',
#  '등',
#  '등등',
#  '제',
#  '겨우',
#  '단지',
#  '다만',
#  '할뿐',
#  '딩동',
#  '댕그',
#  '대해서',
#  '대하여',
#  '대하면',
#  '훨씬',
#  '얼마나',
#  '얼마만큼',
#  '얼마큼',
#  '남짓',
#  '여',
#  '얼마간',
#  '약간',
#  '다소',
#  '좀',
#  '조금',
#  '다수',
#  '몇',
#  '얼마',
#  '지만',
#  '하물며',
#  '또한',
#  '그러나',
#  '그렇지만',
#  '하지만',
#  '이외에도',
#  '대해 말하자면',
#  '뿐이다',
#  '다음에',
#  '반대로',
#  '반대로 말하자면',
#  '이와 반대로',
#  '바꾸어서 말하면',
#  '바꾸어서 한다면',
#  '만약',
#  '그렇지않으면',
#  '까악',
#  '툭',
#  '딱',
#  '삐걱거리다',
#  '보드득',
#  '비걱거리다',
#  '꽈당',
#  '응당',
#  '해야한다',
#  '에 가서',
#  '각',
#  '각각',
#  '여러분',
#  '각종',
#  '각자',
#  '제각기',
#  '하도록하다',
#  '와',
#  '과',
#  '그러므로',
#  '그래서',
#  '고로',
#  '한 까닭에',
#  '하기 때문에',
#  '거니와',
#  '이지만',
#  '대하여',
#  '관하여',
#  '관한',
#  '과연',
#  '실로',
#  '아니나다를가',
#  '생각한대로',
#  '진짜로',
#  '한적이있다',
#  '하곤하였다',
#  '하',
#  '하하',
#  '허허',
#  '아하',
#  '거바',
#  '와',
#  '오',
#  '왜',
#  '어째서',
#  '무엇때문에',
#  '어찌',
#  '하겠는가',
#  '무슨',
#  '어디',
#  '어느곳',
#  '더군다나',
#  '하물며',
#  '더욱이는',
#  '어느때',
#  '언제',
#  '야',
#  '이봐',
#  '어이',
#  '여보시오',
#  '흐흐',
#  '흥',
#  '휴',
#  '헉헉',
#  '헐떡헐떡',
#  '영차',
#  '여차',
#  '어기여차',
#  '끙끙',
#  '아야',
#  '앗',
#  '아야',
#  '콸콸',
#  '졸졸',
#  '좍좍',
#  '뚝뚝',
#  '주룩주룩',
#  '솨',
#  '우르르',
#  '그래도',
#  '또',
#  '그리고',
#  '바꾸어말하면',
#  '바꾸어말하자면',
#  '혹은',
#  '혹시',
#  '답다',
#  '및',
#  '그에 따르는',
#  '때가 되어',
#  '즉',
#  '지든지',
#  '설령',
#  '가령',
#  '하더라도',
#  '할지라도',
#  '일지라도',
#  '지든지',
#  '몇',
#  '거의',
#  '하마터면',
#  '인젠',
#  '이젠',
#  '된바에야',
#  '된이상',
#  '만큼어찌됏든',
#  '그위에',
#  '게다가',
#  '점에서 보아',
#  '비추어 보아',
#  '고려하면',
#  '하게될것이다',
#  '일것이다',
#  '비교적',
#  '좀',
#  '보다더',
#  '비하면',
#  '시키다',
#  '하게하다',
#  '할만하다',
#  '의해서',
#  '연이서',
#  '이어서',
#  '잇따라',
#  '뒤따라',
#  '뒤이어',
#  '결국',
#  '의지하여',
#  '기대여',
#  '통하여',
#  '자마자',
#  '더욱더',
#  '불구하고',
#  '얼마든지',
#  '마음대로',
#  '주저하지 않고',
#  '곧',
#  '즉시',
#  '바로',
#  '당장',
#  '하자마자',
#  '밖에 안된다',
#  '하면된다',
#  '그래',
#  '그렇지',
#  '요컨대',
#  '다시 말하자면',
#  '바꿔 말하면',
#  '즉',
#  '구체적으로',
#  '말하자면',
#  '시작하여',
#  '시초에',
#  '이상',
#  '허',
#  '헉',
#  '허걱',
#  '바와같이',
#  '해도좋다',
#  '해도된다',
#  '게다가',
#  '더구나',
#  '하물며',
#  '와르르',
#  '팍',
#  '퍽',
#  '펄렁',
#  '동안',
#  '이래',
#  '하고있었다',
#  '이었다',
#  '에서',
#  '로부터',
#  '까지',
#  '예하면',
#  '했어요',
#  '해요',
#  '함께',
#  '같이',
#  '더불어',
#  '마저',
#  '마저도',
#  '양자',
#  '모두',
#  '습니다',
#  '가까스로',
#  '하려고하다',
#  '즈음하여',
#  '다른',
#  '다른 방면으로',
#  '해봐요',
#  '습니까',
#  '했어요',
#  '말할것도 없고',
#  '무릎쓰고',
#  '개의치않고',
#  '하는것만 못하다',
#  '하는것이 낫다',
#  '매',
#  '매번',
#  '들',
#  '모',
#  '어느것',
#  '어느',
#  '로써',
#  '갖고말하자면',
#  '어디',
#  '어느쪽',
#  '어느것',
#  '어느해',
#  '어느 년도',
#  '라 해도',
#  '언젠가',
#  '어떤것',
#  '어느것',
#  '저기',
#  '저쪽',
#  '저것',
#  '그때',
#  '그럼',
#  '그러면',
#  '요만한걸',
#  '그래',
#  '그때',
#  '저것만큼',
#  '그저',
#  '이르기까지',
#  '할 줄 안다',
#  '할 힘이 있다',
#  '너',
#  '너희',
#  '당신',
#  '어찌',
#  '설마',
#  '차라리',
#  '할지언정',
#  '할지라도',
#  '할망정',
#  '할지언정',
#  '구토하다',
#  '게우다',
#  '토하다',
#  '메쓰겁다',
#  '옆사람',
#  '퉤',
#  '쳇',
#  '의거하여',
#  '근거하여',
#  '의해',
#  '따라',
#  '힘입어',
#  '그',
#  '다음',
#  '버금',
#  '두번째로',
#  '기타',
#  '첫번째로',
#  '나머지는',
#  '그중에서',
#  '견지에서',
#  '형식으로 쓰여',
#  '입장에서',
#  '위해서',
#  '단지',
#  '의해되다',
#  '하도록시키다',
#  '뿐만아니라',
#  '반대로',
#  '전후',
#  '전자',
#  '앞의것',
#  '잠시',
#  '잠깐',
#  '하면서',
#  '그렇지만',
#  '다음에',
#  '그러한즉',
#  '그런즉',
#  '남들',
#  '아무거나',
#  '어찌하든지',
#  '같다',
#  '비슷하다',
#  '예컨대',
#  '이럴정도로',
#  '어떻게',
#  '만약',
#  '만일',
#  '위에서 서술한바와같이',
#  '인 듯하다',
#  '하지 않는다면',
#  '만약에',
#  '무엇',
#  '무슨',
#  '어느',
#  '어떤',
#  '아래윗',
#  '조차',
#  '한데',
#  '그럼에도 불구하고',
#  '여전히',
#  '심지어',
#  '까지도',
#  '조차도',
#  '하지 않도록',
#  '않기 위하여',
#  '때',
#  '시각',
#  '무렵',
#  '시간',
#  '동안',
#  '어때',
#  '어떠한',
#  '하여금',
#  '네',
#  '예',
#  '우선',
#  '누구',
#  '누가 알겠는가',
#  '아무도',
#  '줄은모른다',
#  '줄은 몰랏다',
#  '하는 김에',
#  '겸사겸사',
#  '하는바',
#  '그런 까닭에',
#  '한 이유는',
#  '그러니',
#  '그러니까',
#  '때문에',
#  '그',
#  '너희',
#  '그들',
#  '너희들',
#  '타인',
#  '것',
#  '것들',
#  '너',
#  '위하여',
#  '공동으로',
#  '동시에',
#  '하기 위하여',
#  '어찌하여',
#  '무엇때문에',
#  '붕붕',
#  '윙윙',
#  '나',
#  '우리',
#  '엉엉',
#  '휘익',
#  '윙윙',
#  '오호',
#  '아하',
#  '어쨋든',
#  '만 못하다하기보다는',
#  '차라리',
#  '하는 편이 낫다',
#  '흐흐',
#  '놀라다',
#  '상대적으로 말하자면',
#  '마치',
#  '아니라면',
#  '쉿',
#  '그렇지 않으면',
#  '그렇지 않다면',
#  '안 그러면',
#  '아니었다면',
#  '하든지',
#  '아니면',
#  '이라면',
#  '좋아',
#  '알았어',
#  '하는것도',
#  '그만이다',
#  '어쩔수 없다',
#  '하나',
#  '일',
#  '일반적으로',
#  '일단',
#  '한켠으로는',
#  '오자마자',
#  '이렇게되면',
#  '이와같다면',
#  '전부',
#  '한마디',
#  '한항목',
#  '근거로',
#  '하기에',
#  '아울러',
#  '하지 않도록',
#  '않기 위해서',
#  '이르기까지',
#  '이 되다',
#  '로 인하여',
#  '까닭으로',
#  '이유만으로',
#  '이로 인하여',
#  '그래서',
#  '이 때문에',
#  '그러므로',
#  '그런 까닭에',
#  '알 수 있다',
#  '결론을 낼 수 있다',
#  '으로 인하여',
#  '있다',
#  '어떤것',
#  '관계가 있다',
#  '관련이 있다',
#  '연관되다',
#  '어떤것들',
#  '에 대해',
#  '이리하여',
#  '그리하여',
#  '여부',
#  '하기보다는',
#  '하느니',
#  '하면 할수록',
#  '운운',
#  '이러이러하다',
#  '하구나',
#  '하도다',
#  '다시말하면',
#  '다음으로',
#  '에 있다',
#  '에 달려 있다',
#  '우리',
#  '우리들',
#  '오히려',
#  '하기는한데',
#  '어떻게',
#  '어떻해',
#  '어찌됏어',
#  '어때',
#  '어째서',
#  '본대로',
#  '자',
#  '이',
#  '이쪽',
#  '여기',
#  '이것',
#  '이번',
#  '이렇게말하자면',
#  '이런',
#  '이러한',
#  '이와 같은',
#  '요만큼',
#  '요만한 것',
#  '얼마 안 되는 것',
#  '이만큼',
#  '이 정도의',
#  '이렇게 많은 것',
#  '이와 같다',
#  '이때',
#  '이렇구나',
#  '것과 같이',
#  '끼익',
#  '삐걱',
#  '따위',
#  '와 같은 사람들',
#  '부류의 사람들',
#  '왜냐하면',
#  '중의하나',
#  '오직',
#  '오로지',
#  '에 한하다',
#  '하기만 하면',
#  '도착하다',
#  '까지 미치다',
#  '도달하다',
#  '정도에 이르다',
#  '할 지경이다',
#  '결과에 이르다',
#  '관해서는',
#  '여러분',
#  '하고 있다',
#  '한 후',
#  '혼자',
#  '자기',
#  '자기집',
#  '자신',
#  '우에 종합한것과같이',
#  '총적으로 보면',
#  '총적으로 말하면',
#  '총적으로',
#  '대로 하다',
#  '으로서',
#  '참',
#  '그만이다',
#  '할 따름이다',
#  '쿵',
#  '탕탕',
#  '쾅쾅',
#  '둥둥',
#  '봐',
#  '봐라',
#  '아이야',
#  '아니',
#  '와아',
#  '응',
#  '아이',
#  '참나',
#  '년',
#  '월',
#  '일',
#  '령',
#  '영',
#  '일',
#  '이',
#  '삼',
#  '사',
#  '오',
#  '육',
#  '륙',
#  '칠',
#  '팔',
#  '구',
#  '이천육',
#  '이천칠',
#  '이천팔',
#  '이천구',
#  '하나',
#  '둘',
#  '셋',
#  '넷',
#  '다섯',
#  '여섯',
#  '일곱',
#  '여덟',
#  '아홉',
#  '령',
#  '영',
#  '이',
#  '있',
#  '하',
#  '것',
#  '들',
#  '그',
#  '되',
#  '수',
#  '이',
#  '보',
#  '않',
#  '없',
#  '나',
#  '사람',
#  '주',
#  '아니',
#  '등',
#  '같',
#  '우리',
#  '때',
#  '년',
#  '가',
#  '한 지',
#  '대하',
#  '오',
#  '말',
#  '일',
#  '그렇',
#  '위하',
#  '때문',
#  '그것',
#  '두',
#  '말하',
#  '알',
#  '그러나',
#  '받',
#  '못하',
#  '일',
#  '그런',
#  '또',
#  '문제',
#  '더',
#  '사회',
#  '많',
#  '그리고',
#  '좋',
#  '크',
#  '따르',
#  '중',
#  '나오',
#  '가지',
#  '씨',
#  '시키',
#  '만들',
#  '지금',
#  '생각하',
#  '그러',
#  '속',
#  '하나',
#  '집',
#  '살',
#  '모르',
#  '적',
#  '월',
#  '데',
#  '자신',
#  '안',
#  '어떤',
#  '내',
#  '내 경우',
#  '명',
#  '생각하',
#  '시간',
#  '그녀',
#  '다시 이런',
#  '앞',
#  '보이',
#  '번',
#  '나오',
#  '다른',
#  '어떻',
#  '여자',
#  '개',
#  '전',
#  '들',
#  '사실',
#  '이렇',
#  '점',
#  '싶',
#  '말',
#  '정도',
#  '좀',
#  '원',
#  '잘',
#  '통하',
#  '놓']

# %%
print(te)
# Out:
# 우리	NP,*,F,우리,*,*,*,*
# 생활	NNG,행위,T,생활,*,*,*,*
# 속	NNG,*,T,속,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 김혜영	NNP,인명,T,김혜영,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 2019113108	SN,*,*,*,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 동국	NNG,*,T,동국,*,*,*,*
# 대학교	NNG,*,F,대학교,Compound,*,*,대/NNG/*+학교/NNG/*
# 글로벌	NNG,*,T,글로벌,*,*,*,*
# 무역	NNG,행위,T,무역,*,*,*,*
# 학과	NNG,*,F,학과,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 서론	NNG,*,T,서론,*,*,*,*
# 1	SN,*,*,*,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 동영상	NNG,*,T,동영상,Compound,*,*,동/NNG/*+영상/NNG/*
# 의	JKG,*,F,의,*,*,*,*
# 주요	NNG,*,F,주요,*,*,*,*
# 내용	NNG,*,T,내용,*,*,*,*
# 이나	JC,*,F,이나,*,*,*,*
# 흥미	NNG,정적사태,F,흥미,*,*,*,*
# 롭	XSA,*,T,롭,*,*,*,*
# 거나	EC,*,F,거나,*,*,*,*
# 관심	NNG,행위,T,관심,*,*,*,*
# 있	VA,*,T,있,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 던	ETM,*,T,던,*,*,*,*
# 내용	NNG,*,T,내용,*,*,*,*
# 소개	NNG,행위,F,소개,*,*,*,*
# :	SC,*,*,*,*,*,*,*
# 이	MM,~명사,F,이,*,*,*,*
# 동영상	NNG,*,T,동영상,Compound,*,*,동/NNG/*+영상/NNG/*
# 은	JX,*,T,은,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대해	VV+EC,*,F,대해,Inflect,VV,EC,대하/VV/*+아/EC/*
# 다룬	VV+ETM,*,T,다룬,Inflect,VV,ETM,다루/VV/*+ᆫ/ETM/*
# 영상	NNG,*,T,영상,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 연설자	NNG,*,F,연설자,Compound,*,*,연설/NNG/행위+자/NNG/*
# 휴	IC,*,F,휴,*,*,*,*
# 허	VV,*,F,허,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 산악	NNG,장소,T,산악,*,*,*,*
# 등	NNB,*,T,등,*,*,*,*
# 반	XPN,*,T,반,*,*,*,*
# 사고	NNG,*,F,사고,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 동상	NNG,*,T,동상,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 입	VV,*,T,입,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 두	MM,~가산명사,F,두,*,*,*,*
# 다리	NNG,*,F,다리,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 절단	NNG,행위,T,절단,*,*,*,*
# 한	XSV+ETM,*,T,한,Inflect,XSV,ETM,하/XSV/*+ᆫ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 계기	NNG,*,F,계기,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 사람	NNG,*,T,사람,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 제거	NNG,행위,F,제거,*,*,*,*
# 할	XSV+ETM,*,T,할,Inflect,XSV,ETM,하/XSV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 필요	NNG,정적사태,F,필요,*,*,*,*
# 하	XSA,*,F,하,*,*,*,*
# 다고	EC,*,F,다고,*,*,*,*
# 생각	NNG,행위,T,생각,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 더	MAG,성분부사|정도부사,F,더,*,*,*,*
# 좋	VA,*,T,좋,*,*,*,*
# 아	EC,*,F,아,*,*,*,*
# 져	VX+EC,*,F,져,Inflect,VX,EC,지/VX/*+어/EC/*
# 언젠가	MAG,성분부사|시간부사,F,언젠가,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 미래	NNG,*,F,미래,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 팔다리	NNG,*,F,팔다리,Compound,*,*,팔/NNG/*+다리/NNG/*
# 세	MM,~가산명사,F,세,*,*,*,*
# 군데	NNBC,*,F,군데,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 부상	NNG,*,T,부상,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 완전히	MAG,성분부사|정도부사,F,완전히,*,*,*,*
# 회복	NNG,상태변화,T,회복,*,*,*,*
# 시킬	XSV+ETM,*,T,시킬,Inflect,XSV,ETM,시키/XSV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 어야	EC,*,F,어야,*,*,*,*
# 한다고	VX+EC,*,F,한다고,Inflect,VX,EC,하/VX/*+ᆫ다고/EC/*
# 생각	NNG,행위,T,생각,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# MIT	SL,*,*,*,*,*,*,*
# 미디어	NNG,*,F,미디어,*,*,*,*
# 랩	NNG,*,T,랩,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 극단	NNG,*,T,극단,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 센터	NNG,*,F,센터,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 설립	NNG,행위,T,설립,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 여러	MM,~가산명사,F,여러,*,*,*,*
# 연구	NNG,행위,F,연구,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 통해	VV+EC,*,F,통해,Inflect,VV,EC,통하/VV/*+아/EC/*
# 연동	NNG,*,T,연동,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 조직	NNG,*,T,조직,*,*,*,*
# 전체	NNG,*,F,전체,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 변화	NNG,상태변화,F,변화,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 따라	VV+EC,*,F,따라,Inflect,VV,EC,따르/VV/*+아/EC/*
# 일어나	VV,*,F,일어나,*,*,*,*
# 야	EC,*,F,야,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 최적	NNG,정적사태,T,최적,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 시점	NNG,*,T,시점,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 찾	VV,*,T,찾,*,*,*,*
# 아	EC,*,F,아,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 만들	VV,*,T,만들,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 냈	VX+EP,*,T,냈,Inflect,VX,EP,내/VX/*+었/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 또	MAG,성분부사|시간부사,F,또,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 미래	NNG,*,F,미래,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 옷	NNG,*,T,옷,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 신발	NNG,*,T,신발,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 보조	NNG,*,F,보조,*,*,*,*
# 기	VCP+ETN,*,F,기,Inflect,VCP,ETN,이/VCP/*+기/ETN/*
# ,	SC,*,*,*,*,*,*,*
# 인공	NNG,*,T,인공,*,*,*,*
# 기관	NNG,*,T,기관,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 더	MAG,성분부사|정도부사,F,더,*,*,*,*
# 이상	NNG,*,T,이상,*,*,*,*
# 디자인	NNG,행위,T,디자인,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 거나	EC,*,F,거나,*,*,*,*
# 자동	NNG,정적사태,T,자동,*,*,*,*
# 화	XSN,*,F,화,*,*,*,*
# 과정	NNG,*,T,과정,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 생산	NNG,행위,T,생산,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKC,*,F,이,*,*,*,*
# 아닌	VCN+ETM,*,T,아닌,Inflect,VCN,ETM,아니/VCN/*+ᆫ/ETM/*
# 자료	NNG,*,F,자료,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 이용	NNG,*,T,이용,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 수치	NNG,*,F,수치,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 체계	NNG,*,F,체계,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 통해	VV+EC,*,F,통해,Inflect,VV,EC,통하/VV/*+아/EC/*
# 생산	NNG,행위,T,생산,*,*,*,*
# 될	XSV+ETM,*,T,될,Inflect,XSV,ETM,되/XSV/*+ᆯ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라고	EC,*,F,라고,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 두	MM,~가산명사,F,두,*,*,*,*
# 가지	NNBC,*,F,가지,*,*,*,*
# 사례	NNG,*,F,사례,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 더	MAG,성분부사|정도부사,F,더,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 후	NNG,*,F,후,*,*,*,*
# 보스톤	NNP,인명,T,보스톤,*,*,*,*
# 테러	NNG,*,F,테러,*,*,*,*
# 사건	NNG,*,T,사건,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 왼쪽	NNG,*,T,왼쪽,Compound,*,*,왼/NNG/*+쪽/NNG/*
# 다리	NNG,*,F,다리,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 잃	VV,*,T,잃,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 무도회	NNG,*,F,무도회,Compound,*,*,무도/NNG/*+회/NNG/*
# 댄서	NNG,*,F,댄서,*,*,*,*
# 아드리안	NNP,인명,T,아드리안,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 이야기	NNG,*,F,이야기,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 연설자	NNG,*,F,연설자,Compound,*,*,연설/NNG/행위+자/NNG/*
# 는	JX,*,T,는,*,*,*,*
# 그녀	NP,*,F,그녀,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 만들	VV,*,T,만들,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 주	VX,*,F,주,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 그녀	NP,*,F,그녀,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 삶	NNG,행위,T,삶,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 춤	NNG,행위,T,춤,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 되돌아갈	VV+ETM,*,T,되돌아갈,Inflect,VV,ETM,되돌아가/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 도록	EC,*,T,도록,*,*,*,*
# 해	VV+EC,*,F,해,Inflect,VV,EC,하/VV/*+아/EC/*
# 주	VX,*,F,주,*,*,*,*
# 자는	ETM,*,T,자는,*,*,*,*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 200	SN,*,*,*,*,*,*,*
# 일	NNBC,*,T,일,*,*,*,*
# 이상	NNG,*,T,이상,*,*,*,*
# 춤	NNG,행위,T,춤,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대해	VV+EC,*,F,대해,Inflect,VV,EC,대하/VV/*+아/EC/*
# 연구	NNG,행위,F,연구,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 아드리안	NNP,인명,T,아드리안,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 통해	VV+EC,*,F,통해,Inflect,VV,EC,통하/VV/*+아/EC/*
# 무대	NNG,장소,F,무대,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 설	VV+ETM,*,T,설,Inflect,VV,ETM,서/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 도록	EC,*,T,도록,*,*,*,*
# 해	VV+EC,*,F,해,Inflect,VV,EC,하/VV/*+아/EC/*
# 주	VX,*,F,주,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 영상	NNG,*,T,영상,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 아드리안	NNP,인명,T,아드리안,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 춤	NNG,행위,T,춤,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 마무리	NNG,행위,F,마무리,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 미래	NNG,*,F,미래,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 어떤	MM,~명사,T,어떤,*,*,*,*
# 변화	NNG,상태변화,F,변화,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 불러올지	VV+EC,*,F,불러올지,Inflect,VV,EC,불러오/VV/*+ᆯ지/EC/*
# ,	SC,*,*,*,*,*,*,*
# 그	MM,~명사,F,그,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 인간	NNG,*,T,인간,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 얼마나	MAG,성분부사|정도부사,F,얼마나,*,*,*,*
# 도움	NNG,행위,T,도움,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 는지	EC,*,F,는지,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 설명	NNG,*,T,설명,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 주요	NNG,*,F,주요,*,*,*,*
# 내용	NNG,*,T,내용,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 나	NP,*,F,나,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 두	MM,~가산명사,F,두,*,*,*,*
# 다리	NNG,*,F,다리,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 절단	NNG,행위,T,절단,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였음에도	EP+ETN+JKB+JX,*,F,였음에도,Inflect,EP,JX,았/EP/*+음/ETN/*+에/JKB/*+도/JX/*
# 좌절	NNG,행위,T,좌절,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 오히려	MAJ,*,F,오히려,*,*,*,*
# 다른	MM,~명사,T,다른,*,*,*,*
# 사람	NNG,*,T,사람,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 제거	NNG,행위,F,제거,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 발전	NNG,행위,T,발전,*,*,*,*
# 된	XSV+ETM,*,T,된,Inflect,XSV,ETM,되/XSV/*+ᆫ/ETM/*
# 기술	NNG,*,T,기술,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 가져야	VV+EC+VX,*,F,가져야,Inflect,VV,VX,가지/VV/*+어야/EC/*+하/VX/*
# 겠	EP,*,T,겠,*,*,*,*
# 다는	ETM,*,T,다는,*,*,*,*
# 미래	NNG,*,F,미래,*,*,*,*
# 지향	NNG,행위,T,지향,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 한	VV+ETM,*,T,한,Inflect,VV,ETM,하/VV/*+ᆫ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 정말	MAG,문장부사|양상부사,T,정말,*,*,*,*
# 대단	XR,*,T,대단,*,*,*,*
# 하	XSA,*,F,하,*,*,*,*
# 다고	EC,*,F,다고,*,*,*,*
# 생각	NNG,행위,T,생각,*,*,*,*
# 했	XSV+EP,*,T,했,Inflect,XSV,EP,하/XSV/*+았/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 만약	MAG,문장부사|양상부사,T,만약,*,*,*,*
# 나	NP,*,F,나,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 이런	MM,~명사,T,이런,*,*,*,*
# 일	NNG,*,T,일,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 생겼	VV+EP,*,T,생겼,Inflect,VV,EP,생기/VV/*+었/EP/*
# 더라면	EC,*,T,더라면,*,*,*,*
# 앞	NNG,장소,T,앞,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 살아갈	VV+ETM,*,T,살아갈,Inflect,VV,ETM,살아가/VV/*+ᆯ/ETM/*
# 미래	NNG,*,F,미래,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대한	VV+ETM,*,T,대한,Inflect,VV,ETM,대하/VV/*+ᆫ/ETM/*
# 걱정	NNG,정적사태,T,걱정,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 좌절	NNG,행위,T,좌절,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 먼저	MAG,성분부사|시간부사,F,먼저,*,*,*,*
# 앞섰	VV+EP,*,T,앞섰,Inflect,VV,EP,앞서/VV/*+었/EP/*
# 을	ETM,*,T,을,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 은데	EC,*,F,은데,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 위	NNG,*,F,위,*,*,*,*
# 와	JKB,*,F,와,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 개발	NNG,행위,T,개발,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 센터	NNG,*,F,센터,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 설립	NNG,행위,T,설립,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 연설	NNG,행위,T,연설,*,*,*,*
# 까지	JX,*,F,까지,*,*,*,*
# 할	VV+ETM,*,T,할,Inflect,VV,ETM,하/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 다는	ETM,*,T,다는,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라	EC,*,F,라,*,*,*,*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 걱정	NNG,정적사태,T,걱정,*,*,*,*
# 가득	MAG,성분부사|양태부사,T,가득,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 부정	NNG,정적사태,T,부정,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 먼저	MAG,성분부사|시간부사,F,먼저,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 나	NP,*,F,나,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 돌아보	VV,*,F,돌아보,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 던	ETM,*,T,던,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 흥미	NNG,정적사태,F,흥미,*,*,*,*
# 로웠	XSA+EP,*,T,로웠,Inflect,XSA,EP,롭/XSA/*+었/EP/*
# 던	ETM,*,T,던,*,*,*,*
# 부분	NNG,*,T,부분,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 사례	NNG,*,F,사례,*,*,*,*
# 로	JKB,*,F,로,*,*,*,*
# 나왔	VV+EP,*,T,나왔,Inflect,VV,EP,나오/VV/*+았/EP/*
# 던	ETM,*,T,던,*,*,*,*
# 분	NNB,*,T,분,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 영상	NNG,*,T,영상,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 다리	NNG,*,F,다리,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# 팔	NNG,*,T,팔,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 잃	VV,*,T,잃,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 의수족	NNG,*,T,의수족,Compound,*,*,의/NNG/*+수족/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 착용	NNG,행위,T,착용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 다시	MAG,성분부사|시간부사,F,다시,*,*,*,*
# 이전	NNG,*,T,이전,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 동일	NNG,*,T,동일,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 삶	NNG,행위,T,삶,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 살아간다는	VV+ETM,*,T,살아간다는,Inflect,VV,ETM,살아가/VV/*+ᆫ다는/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 따뜻	XR,*,T,따뜻,*,*,*,*
# 하	XSA,*,F,하,*,*,*,*
# 면서	EC,*,F,면서,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 감동	NNG,정적사태,T,감동,*,*,*,*
# 받	VV,*,T,받,*,*,*,*
# 았	EP,*,T,았,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 본론	NNG,*,T,본론,*,*,*,*
# 1	SN,*,*,*,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 발레리나	NNG,*,F,발레리나,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 춤출	VV+ETM,*,T,춤출,Inflect,VV,ETM,춤추/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 위해	VV+EC,*,F,위해,Inflect,VV,EC,위하/VV/*+아/EC/*
# 어떤	MM,~명사,T,어떤,*,*,*,*
# 노력	NNG,*,T,노력,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 해	VV+EC,*,F,해,Inflect,VV,EC,하/VV/*+아/EC/*
# 왔	VX+EP,*,T,왔,Inflect,VX,EP,오/VX/*+았/EP/*
# 나요	EF,*,F,나요,*,*,*,*
# ?	SF,*,*,*,*,*,*,*
# :	SC,*,*,*,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 로봇	NNG,*,T,로봇,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 기계	NNG,*,F,기계,*,*,*,*
# 학습	NNG,행위,T,학습,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 기계학	NNG,*,T,기계학,Compound,*,*,기계/NNG/*+학/NNG/*
# 전문가	NNG,*,F,전문가,Compound,*,*,전문/NNG/*+가/NNG/*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# MIT	SL,*,*,*,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 과학자	NNG,*,F,과학자,Compound,*,*,과학/NNG/*+자/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 초청	NNG,행위,T,초청,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 여	EC,*,F,여,*,*,*,*
# 200	SN,*,*,*,*,*,*,*
# 일	NNBC,*,T,일,*,*,*,*
# 이상	NNG,*,T,이상,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 연구	NNG,행위,F,연구,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 거쳐	VV+EC,*,F,거쳐,Inflect,VV,EC,거치/VV/*+어/EC/*
# 춤	NNG,행위,T,춤,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대해	VV+EC,*,F,대해,Inflect,VV,EC,대하/VV/*+아/EC/*
# 연구	NNG,행위,F,연구,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 또	MAG,성분부사|시간부사,F,또,*,*,*,*
# 정상	NNG,*,T,정상,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 댄서	NNG,*,F,댄서,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 초청	NNG,행위,T,초청,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 여	EC,*,F,여,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 어떻게	MAG,*,F,어떻게,*,*,*,*
# 움직이	VV,*,F,움직이,*,*,*,*
# 는지	EC,*,F,는지,*,*,*,*
# 그리고	MAJ,*,F,그리고,*,*,*,*
# 무대	NNG,장소,F,무대,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 어떤	MM,~명사,T,어떤,*,*,*,*
# 힘	NNG,*,T,힘,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는지	EC,*,F,는지,*,*,*,*
# 연구	NNG,행위,F,연구,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 그	MM,~명사,F,그,*,*,*,*
# 자료	NNG,*,F,자료,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 가져다	VV+EC,*,F,가져다,Inflect,VV,EC,가지/VV/*+어다/EC/*
# 춤	NNG,행위,T,춤,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 기본	NNG,*,T,기본,*,*,*,*
# 원리	NNG,*,F,원리,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# 유연	XR,*,T,유연,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 춤	NNG,행위,T,춤,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 능력	NNG,*,T,능력,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 적용	NNG,행위,T,적용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 여	EC,*,F,여,*,*,*,*
# 그	MM,~명사,F,그,*,*,*,*
# 지식	NNG,*,T,지식,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 내장	NNG,*,T,내장,*,*,*,*
# 시켰	XSV+EP,*,T,시켰,Inflect,XSV,EP,시키/XSV/*+었/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 본론	NNG,*,T,본론,*,*,*,*
# 2	SN,*,*,*,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 개별	NNG,*,T,개별,*,*,*,*
# 질문	NNG,행위,T,질문,*,*,*,*
# 소개	NNG,행위,F,소개,*,*,*,*
# 와	JC,*,F,와,*,*,*,*
# 내	NP+JKG,*,F,내,Inflect,NP,JKG,나/NP/*+의/JKG/*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# :	SC,*,*,*,*,*,*,*
# 이	MM,~명사,F,이,*,*,*,*
# 영상	NNG,*,T,영상,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 보	VV,*,F,보,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 들	VX,*,T,들,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 던	ETM,*,T,던,*,*,*,*
# 질문	NNG,행위,T,질문,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# “	SSO,*,*,*,*,*,*,*
# 첫	MM,~명사,T,첫,*,*,*,*
# 번	NNBC,*,T,번,*,*,*,*
# 째	XSN,*,F,째,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 과연	MAG,문장부사|양상부사,T,과연,*,*,*,*
# 연설자	NNG,*,F,연설자,Compound,*,*,연설/NNG/행위+자/NNG/*
# 휴	IC,*,F,휴,*,*,*,*
# 허	VV,*,F,허,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 자원	NNG,*,T,자원,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 더라도	EC,*,F,더라도,*,*,*,*
# 똑같	VA,*,T,똑같,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 일	NNG,*,T,일,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 했	VV+EP,*,T,했,Inflect,VV,EP,하/VV/*+았/EP/*
# 을까	EF,*,F,을까,*,*,*,*
# ?	SF,*,*,*,*,*,*,*
# 그리고	MAJ,*,F,그리고,*,*,*,*
# 두	MM,~가산명사,F,두,*,*,*,*
# 번	NNBC,*,T,번,*,*,*,*
# 째	XSN,*,F,째,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 사람	NNG,*,T,사람,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 많	VA,*,T,많,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 분	NNB,*,T,분,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 많	VA,*,T,많,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 이유	NNG,*,F,이유,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 무엇	NP,*,T,무엇,*,*,*,*
# 일까	VCP+EF,*,F,일까,Inflect,VCP,EF,이/VCP/*+ᆯ까/EF/*
# ?	SF,*,*,*,*,*,*,*
# “	SSO,*,*,*,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대한	VV+ETM,*,T,대한,Inflect,VV,ETM,대하/VV/*+ᆫ/ETM/*
# 나	NP,*,F,나,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 와	JKB,*,F,와,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 첫	MM,~명사,T,첫,*,*,*,*
# 번	NNBC,*,T,번,*,*,*,*
# 째	XSN,*,F,째,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 휴	IC,*,F,휴,*,*,*,*
# 허	VV,*,F,허,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 자원	NNG,*,T,자원,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 더라도	EC,*,F,더라도,*,*,*,*
# 충분히	MAG,성분부사|정도부사,F,충분히,*,*,*,*
# 똑같	VA,*,T,똑같,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 일	NNG,*,T,일,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 했	VV+EP,*,T,했,Inflect,VV,EP,하/VV/*+았/EP/*
# 을	ETM,*,T,을,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라	EC,*,F,라,*,*,*,*
# 생각	NNG,행위,T,생각,*,*,*,*
# 한다	XSV+EF,*,F,한다,Inflect,XSV,EF,하/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 수술	NNG,*,T,수술,*,*,*,*
# 받	VV,*,T,받,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 지	NNB,*,F,지,*,*,*,*
# 불과	MAG,성분부사|정도부사,F,불과,*,*,*,*
# 7	SN,*,*,*,*,*,*,*
# 주	NNBC,*,F,주,*,*,*,*
# 밖에	JX,*,F,밖에,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 았	EP,*,T,았,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 석고	NNG,*,F,석고,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 족	NNG,*,T,족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 낀	VV+ETM,*,T,낀,Inflect,VV,ETM,끼/VV/*+ᆫ/ETM/*
# 상태	NNG,정적사태,F,상태,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 절벽	NNG,*,T,절벽,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 올랐	VV+EP,*,T,올랐,Inflect,VV,EP,오르/VV/*+았/EP/*
# 고	EC,*,F,고,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 암벽등반	NNP,*,T,암벽등반,Compound,*,*,암벽/NNG/장소+등반/NNG/행위
# 에	JKB,*,F,에,*,*,*,*
# 최적	NNG,정적사태,T,최적,*,*,*,*
# 화	XSN,*,F,화,*,*,*,*
# 된	XSV+ETM,*,T,된,Inflect,XSV,ETM,되/XSV/*+ᆫ/ETM/*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 만들	VV,*,T,만들,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 위해	VV+EC,*,F,위해,Inflect,VV,EC,위하/VV/*+아/EC/*
# 노력	NNG,*,T,노력,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 아끼	VV,*,F,아끼,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 았	EP,*,T,았,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 이후	NNG,*,F,이후,*,*,*,*
# 마침내	MAG,문장부사|접속부사,F,마침내,*,*,*,*
# 본인	NNG,*,T,본인,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 최적	NNG,정적사태,T,최적,*,*,*,*
# 화	XSN,*,F,화,*,*,*,*
# 된	XSV+ETM,*,T,된,Inflect,XSV,ETM,되/XSV/*+ᆫ/ETM/*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 만들	VV+ETM,*,T,만들,Inflect,VV,ETM,만들/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 아드리안	NNP,인명,T,아드리안,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 도	JX,*,F,도,*,*,*,*
# 최고	NNG,*,F,최고,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 선물	NNG,*,T,선물,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 주	VV,*,F,주,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 나	NP,*,F,나,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 휴	IC,*,F,휴,*,*,*,*
# 허	VV,*,F,허,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 자원	NNG,*,T,자원,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 더라도	EC,*,F,더라도,*,*,*,*
# 그	NP,*,F,그,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 강인	XR,*,T,강인,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 열정	NNG,정적사태,T,열정,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 똑같	VA,*,T,똑같,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 일	NNG,*,T,일,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 행하	VV,*,F,행하,*,*,*,*
# 였을	EP+ETM,*,T,였을,Inflect,EP,ETM,았/EP/*+을/ETM/*
# 거	NNB,*,F,거,*,*,*,*
# 라	VCP+EC,*,F,라,Inflect,VCP,EC,이/VCP/*+라/EC/*
# 생각	NNG,행위,T,생각,*,*,*,*
# 한다	XSV+EF,*,F,한다,Inflect,XSV,EF,하/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 두	MM,~가산명사,F,두,*,*,*,*
# 번	NNBC,*,T,번,*,*,*,*
# 째	XSN,*,F,째,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 많이	MAG,성분부사|정도부사,F,많이,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 이유	NNG,*,F,이유,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 높	VA,*,T,높,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 가격	NNG,*,T,가격,*,*,*,*
# 때문	NNB,*,T,때문,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라고	EC,*,F,라고,*,*,*,*
# 생각	NNG,행위,T,생각,*,*,*,*
# 한다	XSV+EF,*,F,한다,Inflect,XSV,EF,하/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 가격	NNG,*,T,가격,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 천차만별	NNG,정적사태,T,천차만별,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 가격대	NNG,*,F,가격대,Compound,*,*,가격/NNG/*+대/NNG/*
# 가	JKS,*,F,가,*,*,*,*
# 높	VA,*,T,높,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 형성	NNG,행위,T,형성,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 되	VV,*,F,되,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 있	VX,*,T,있,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 반면	NNG,정적사태,T,반면,*,*,*,*
# 지원금	NNG,*,T,지원금,Compound,*,*,지원/NNG/*+금/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 받	VV,*,T,받,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 조건	NNG,*,T,조건,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 받	VV,*,T,받,*,*,*,*
# 는다	EC,*,F,는다,*,*,*,*
# 해도	VV+EC,*,F,해도,Inflect,VV,EC,하/VV/*+아도/EC/*
# 워낙	MAG,*,T,워낙,*,*,*,*
# 높	VA,*,T,높,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 가격	NNG,*,T,가격,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 경쟁력	NNG,정적사태,T,경쟁력,Compound,*,*,경쟁/NNG/행위+력/NNG/*
# 이	JKS,*,F,이,*,*,*,*
# 가장	MAG,성분부사|정도부사,T,가장,*,*,*,*
# 큰	VA+ETM,*,T,큰,Inflect,VA,ETM,크/VA/*+ᆫ/ETM/*
# 이유	NNG,*,F,이유,*,*,*,*
# 라고	VCP+EC,*,F,라고,Inflect,VCP,EC,이/VCP/*+라고/EC/*
# 생각	NNG,행위,T,생각,*,*,*,*
# 된다	XSV+EF,*,F,된다,Inflect,XSV,EF,되/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 또	MAG,성분부사|시간부사,F,또,*,*,*,*
# 지원금	NNG,*,T,지원금,Compound,*,*,지원/NNG/*+금/NNG/*
# 은	JX,*,T,은,*,*,*,*
# 3	SN,*,*,*,*,*,*,*
# 년	NNBC,*,T,년,*,*,*,*
# 마다	JX,*,F,마다,*,*,*,*
# 받	VV,*,T,받,*,*,*,*
# 을	ETM,*,T,을,*,*,*,*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 때문	NNB,*,T,때문,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 3	SN,*,*,*,*,*,*,*
# 년	NNBC,*,T,년,*,*,*,*
# 이내	NNG,*,F,이내,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 바꾸	VV,*,F,바꾸,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 된다면	VV+EC,*,T,된다면,Inflect,VV,EC,되/VV/*+ᆫ다면/EC/*
# 지원금	NNG,*,T,지원금,Compound,*,*,지원/NNG/*+금/NNG/*
# 이	JKS,*,F,이,*,*,*,*
# 지불	NNG,행위,T,지불,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 된다	VV+EF,*,F,된다,Inflect,VV,EF,되/VV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 생각	NNG,행위,T,생각,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 면	EC,*,T,면,*,*,*,*
# 아찔	XR,*,T,아찔,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 금액	NNG,*,T,금액,*,*,*,*
# 이	JKC,*,F,이,*,*,*,*
# 아닐	VCN+ETM,*,T,아닐,Inflect,VCN,ETM,아니/VCN/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 을	ETM,*,T,을,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# -	SY,*,*,*,*,*,*,*
# (	SSO,*,*,*,*,*,*,*
# 마무리	NNG,행위,F,마무리,*,*,*,*
# )	SSC,*,*,*,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 개인	NNG,*,T,개인,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 삶	NNG,행위,T,삶,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대한	VV+ETM,*,T,대한,Inflect,VV,ETM,대하/VV/*+ᆫ/ETM/*
# 영향력	NNG,*,T,영향력,Compound,*,*,영향/NNG/*+력/NNG/*
# 을	JKO,*,T,을,*,*,*,*
# 고려	NNG,행위,F,고려,*,*,*,*
# 한다면	XSV+EC,*,T,한다면,Inflect,XSV,EC,하/XSV/*+ᆫ다면/EC/*
# ,	SC,*,*,*,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 앞	NNG,장소,T,앞,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 어떤	MM,~명사,T,어떤,*,*,*,*
# 방향	NNG,*,T,방향,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 발전	NNG,행위,T,발전,*,*,*,*
# 해	XSV+EC,*,F,해,Inflect,XSV,EC,하/XSV/*+아/EC/*
# 가	VX,*,F,가,*,*,*,*
# 야	EC,*,F,야,*,*,*,*
# 할까요	VX+EC,*,F,할까요,Inflect,VX,EC,하/VX/*+ᆯ까요/EC/*
# ?	SY,*,*,*,*,*,*,*
# :	SC,*,*,*,*,*,*,*
# 최근	NNG,*,T,최근,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 본	VV+ETM,*,T,본,Inflect,VV,ETM,보/VV/*+ᆫ/ETM/*
# TV	SL,*,*,*,*,*,*,*
# 광고	NNG,*,F,광고,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 있	VA,*,T,있,*,*,*,*
# 는데	EC,*,F,는데,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 선천	NNG,*,T,선천,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 청각	NNG,*,T,청각,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 김소희	NNP,인명,F,김소희,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대한	VV+ETM,*,T,대한,Inflect,VV,ETM,대하/VV/*+ᆫ/ETM/*
# 광고	NNG,*,F,광고,*,*,*,*
# 였	VCP+EP,*,T,였,Inflect,VCP,EP,이/VCP/*+었/EP/*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 이	MM,~명사,F,이,*,*,*,*
# 광고	NNG,*,F,광고,*,*,*,*
# 내용	NNG,*,T,내용,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 이	NP,*,F,이,*,*,*,*
# 와	JKB,*,F,와,*,*,*,*
# 같	VA,*,T,같,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 선천	NNG,*,T,선천,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 귀	NNG,*,F,귀,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 들리	VV,*,F,들리,*,*,*,*
# 지	EC,*,F,지,*,*,*,*
# 않	VX,*,T,않,*,*,*,*
# 아	EC,*,F,아,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 할	VV+ETM,*,T,할,Inflect,VV,ETM,하/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 없	VA,*,T,없,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 김소희	NNP,인명,F,김소희,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 가족	NNG,*,T,가족,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 한	MM,~가산명사,T,한,*,*,*,*
# 번	NNBC,*,T,번,*,*,*,*
# 이라도	JX,*,F,이라도,*,*,*,*
# 이	NR,*,F,이,*,*,*,*
# 분	NNBC,*,T,분,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 듣	VV,*,T,듣,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 싶	VX,*,T,싶,*,*,*,*
# 어	EC,*,F,어,*,*,*,*
# 하	VV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 김소희	NNP,인명,F,김소희,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 또한	MAJ,*,T,또한,*,*,*,*
# 가족	NNG,*,T,가족,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 본인	NNG,*,T,본인,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 들려주	VV,*,F,들려주,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 소원	NNG,정적사태,T,소원,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라고	EC,*,F,라고,*,*,*,*
# 한다	VX+EF,*,F,한다,Inflect,VX,EF,하/VX/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# KT	SL,*,*,*,*,*,*,*
# 에서	JKB,*,F,에서,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 김소희	NNP,인명,F,김소희,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 추론	NNG,*,T,추론,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 기	ETN,*,F,기,*,*,*,*
# 위해	VV+EC,*,F,위해,Inflect,VV,EC,위하/VV/*+아/EC/*
# 가족	NNG,*,T,가족,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 녹	VV,*,T,녹,*,*,*,*
# 음	ETN,*,T,음,*,*,*,*
# 및	MAJ,*,T,및,*,*,*,*
# 김소희	NNP,인명,F,김소희,*,*,*,*
# 씨	NNB,*,F,씨,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 구강	NNG,*,T,구강,*,*,*,*
# 구조	NNG,*,F,구조,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 분석	NNG,행위,T,분석,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 였	EP,*,T,였,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 이후	NNG,*,F,이후,*,*,*,*
# 기	VCP+EC,*,F,기,Inflect,VCP,EC,이/VCP/*+기/EC/*
# 가지	VX,*,F,가지,*,*,*,*
# 니	EC,*,F,니,*,*,*,*
# AI	SL,*,*,*,*,*,*,*
# 음성	NNG,*,T,음성,*,*,*,*
# 합성	NNG,*,T,합성,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 통해	VV+EC,*,F,통해,Inflect,VV,EC,통하/VV/*+아/EC/*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 실현	NNG,행위,T,실현,*,*,*,*
# 시켜	XSV+EC,*,F,시켜,Inflect,XSV,EC,시키/XSV/*+어/EC/*
# 가족	NNG,*,T,가족,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 에게	JKB,*,F,에게,*,*,*,*
# 들려	VV+EC,*,F,들려,Inflect,VV,EC,들리/VV/*+어/EC/*
# 주	VX,*,F,주,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 동영상	NNG,*,T,동영상,Compound,*,*,동/NNG/*+영상/NNG/*
# 이	JKS,*,F,이,*,*,*,*
# 생체	NNG,*,F,생체,*,*,*,*
# 공학	NNG,*,T,공학,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 의족	NNG,*,T,의족,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 개발	NNG,행위,T,개발,*,*,*,*
# 한	XSV+ETM,*,T,한,Inflect,XSV,ETM,하/XSV/*+ᆫ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 라면	EC,*,T,라면,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# TV	SL,*,*,*,*,*,*,*
# 광고	NNG,*,F,광고,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 목소리	NNG,*,F,목소리,Compound,*,*,목/NNG/*+소리/NNG/*
# 를	JKO,*,T,를,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 통해	VV+EC,*,F,통해,Inflect,VV,EC,통하/VV/*+아/EC/*
# 한정	NNG,*,T,한정,*,*,*,*
# 된	XSV+ETM,*,T,된,Inflect,XSV,ETM,되/XSV/*+ᆫ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# 말	NNG,*,T,말,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 할	VV+ETM,*,T,할,Inflect,VV,ETM,하/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 었	EP,*,T,었,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 연설자	NNG,*,F,연설자,Compound,*,*,연설/NNG/행위+자/NNG/*
# 의	JKG,*,F,의,*,*,*,*
# 생각	NNG,정적사태,T,생각,*,*,*,*
# 처럼	JKB,*,T,처럼,*,*,*,*
# 미래	NNG,*,F,미래,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 인	XSN,*,T,인,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 극복	NNG,행위,T,극복,*,*,*,*
# 할	XSV+ETM,*,T,할,Inflect,XSV,ETM,하/XSV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 는	ETM,*,T,는,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 발전	NNG,행위,T,발전,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 어야	EC,*,F,어야,*,*,*,*
# 한다고	VX+EC,*,F,한다고,Inflect,VX,EC,하/VX/*+ᆫ다고/EC/*
# 생각	NNG,행위,T,생각,*,*,*,*
# 한다	XSV+EF,*,F,한다,Inflect,XSV,EF,하/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 비장	NNG,*,T,비장,*,*,*,*
# 애인	NNG,*,T,애인,*,*,*,*
# 의	JKG,*,F,의,*,*,*,*
# 편리	NNG,*,F,편리,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 위해	VV+EC,*,F,위해,Inflect,VV,EC,위하/VV/*+아/EC/*
# AI	SL,*,*,*,*,*,*,*
# 가	JKS,*,F,가,*,*,*,*
# 발달	NNG,행위,T,발달,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 있	VX,*,T,있,*,*,*,*
# 지만	EC,*,T,지만,*,*,*,*
# ,	SC,*,*,*,*,*,*,*
# 비	XPN,*,F,비,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 뿐	NNB,*,T,뿐,*,*,*,*
# 아니	VCN,*,F,아니,*,*,*,*
# 라	EC,*,F,라,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 인도	NNP,지명,F,인도,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 를	JKO,*,T,를,*,*,*,*
# 극복	NNG,행위,T,극복,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 비장	NNG,*,T,비장,*,*,*,*
# 애인	NNG,*,T,애인,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 동일	NNG,*,T,동일,*,*,*,*
# 한	XSA+ETM,*,T,한,Inflect,XSA,ETM,하/XSA/*+ᆫ/ETM/*
# 삶	NNG,행위,T,삶,*,*,*,*
# 을	JKO,*,T,을,*,*,*,*
# 살아갈	VV+ETM,*,T,살아갈,Inflect,VV,ETM,살아가/VV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 도록	EC,*,T,도록,*,*,*,*
# 발전	NNG,상태변화,T,발전,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 어야	EC,*,F,어야,*,*,*,*
# 한다고	VX+EC,*,F,한다고,Inflect,VX,EC,하/VX/*+ᆫ다고/EC/*
# 생각	NNG,행위,T,생각,*,*,*,*
# 한다	XSV+EF,*,F,한다,Inflect,XSV,EF,하/XSV/*+ᆫ다/EF/*
# .	SF,*,*,*,*,*,*,*
# 그러나	MAJ,*,F,그러나,*,*,*,*
# 현재	NNG,*,F,현재,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 기술	NNG,*,T,기술,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 발달	NNG,행위,T,발달,*,*,*,*
# 했으나	XSV+EP+EC,*,F,했으나,Inflect,XSV,EC,하/XSV/*+았/EP/*+으나/EC/*
# 의족	NNG,*,T,의족,*,*,*,*
# 등	NNB,*,T,등,*,*,*,*
# 가격	NNG,*,T,가격,*,*,*,*
# 은	JX,*,T,은,*,*,*,*
# 천차만별	NNG,정적사태,T,천차만별,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 고	EC,*,F,고,*,*,*,*
# 비싼	VA+ETM,*,T,비싼,Inflect,VA,ETM,비싸/VA/*+ᆫ/ETM/*
# 가격대	NNG,*,F,가격대,Compound,*,*,가격/NNG/*+대/NNG/*
# 에	JKB,*,F,에,*,*,*,*
# 만만	XR,*,T,만만,*,*,*,*
# 치	XSA+EC,*,F,치,Inflect,XSA,EC,하/XSA/*+지/EC/*
# 않	VX,*,T,않,*,*,*,*
# 을	ETM,*,T,을,*,*,*,*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 여러	MM,~가산명사,F,여러,*,*,*,*
# 장애	NNG,*,F,장애,*,*,*,*
# 인	XSN,*,T,인,*,*,*,*
# 들	XSN,*,T,들,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 사용	NNG,행위,T,사용,*,*,*,*
# 할	XSV+ETM,*,T,할,Inflect,XSV,ETM,하/XSV/*+ᆯ/ETM/*
# 수	NNB,*,F,수,*,*,*,*
# 있	VV,*,T,있,*,*,*,*
# 도록	EC,*,T,도록,*,*,*,*
# 앞	NNG,장소,T,앞,*,*,*,*
# 으로	JKB,*,F,으로,*,*,*,*
# 는	JX,*,T,는,*,*,*,*
# 금전	NNG,*,T,금전,*,*,*,*
# 적	XSN,*,T,적,*,*,*,*
# 인	VCP+ETM,*,T,인,Inflect,VCP,ETM,이/VCP/*+ᆫ/ETM/*
# 부분	NNG,*,T,부분,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 대해서	VV+EC,*,F,대해서,Inflect,VV,EC,대하/VV/*+아서/EC/*
# 도	JX,*,F,도,*,*,*,*
# 많	VA,*,T,많,*,*,*,*
# 은	ETM,*,T,은,*,*,*,*
# 고민	NNG,*,T,고민,*,*,*,*
# 과	JC,*,F,과,*,*,*,*
# 조정	NNG,*,T,조정,*,*,*,*
# 이	JKS,*,F,이,*,*,*,*
# 필요	NNG,정적사태,F,필요,*,*,*,*
# 할	XSV+ETM,*,T,할,Inflect,XSV,ETM,하/XSV/*+ᆯ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# 또	MAG,성분부사|시간부사,F,또,*,*,*,*
# 스마트	NNG,*,F,스마트,*,*,*,*
# 하	XSV,*,F,하,*,*,*,*
# 게	EC,*,F,게,*,*,*,*
# 진화	NNG,*,F,진화,*,*,*,*
# 되	XSV,*,F,되,*,*,*,*
# 므로	EC,*,F,므로,*,*,*,*
# 로봇	NNG,*,T,로봇,*,*,*,*
# 에	JKB,*,F,에,*,*,*,*
# 너무	MAG,성분부사|정도부사,F,너무,*,*,*,*
# 의존	NNG,행위,T,의존,*,*,*,*
# 해서	XSV+EC,*,F,해서,Inflect,XSV,EC,하/XSV/*+아서/EC/*
# 도	JX,*,F,도,*,*,*,*
# 안	MAG,성분부사|부정부사,T,안,*,*,*,*
# 될	VV+ETM,*,T,될,Inflect,VV,ETM,되/VV/*+ᆯ/ETM/*
# 것	NNB,*,T,것,*,*,*,*
# 이	VCP,*,F,이,*,*,*,*
# 다	EF,*,F,다,*,*,*,*
# .	SF,*,*,*,*,*,*,*
# EOS
